# %% [markdown]
# # Los Angeles Dataset

# %%
# Import dependencies
import os
import csv
import pandas as pd
import json
from pathlib import Path

# %% [markdown]
# ## Demographic Metric
#
# **Measuring**: ACS Median Age, Racial Demographics, Education Level
#
# Data was pulled from the 2020 Los Angeles Census Database and the American Community Survey (ACS) by the U.S. Census Bureau using various coded tables to ensure unified data for each metropolitan city. Two tables used the same code and were seperated to ensure proper measurement.
# * ACS Median Age: Table DP05
# * ACS Race: Table DP05
# * Education Level: S1501

# %% [markdown]
# ##### ACS Median Age (Table DP05)

# %%
# Import csv file for ACS Population Density
la_age_data = "..\los_angeles_data\la_raw_csv\la_age.csv"

# Read the CSV file into a DataFrame
la_age_df = pd.read_csv(la_age_data)
la_age_df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\910518066.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_age_data = "..\los_angeles_data\la_raw_csv\la_age.csv"
#                Label (Grouping)  SEX AND AGE SEX AND AGE!!Total population  \
# 0  Los Angeles city, California          NaN                           NaN
# 1                      Estimate          NaN                     3,973,278
# 2                       Percent          NaN                     3,973,278
#
#   SEX AND AGE!!Total population!!Under 5 years  \
# 0                                          NaN
# 1                                      226,227
# 2                                         5.7%
#
#   SEX AND AGE!!Total population!!5 to 9 years  \
# 0                                         NaN
# 1                                     224,155
# 2                                        5.6%
#
#   SEX AND AGE!!Total population!!10 to 14 years  \
# 0                                           NaN
# 1                                       225,304
# 2                                          5.7%
#
#   SEX AND AGE!!Total population!!15 to 19 years  \
# 0                                           NaN
# 1                                       237,653
# 2                                          6.0%
#
#   SEX AND AGE!!Total population!!20 to 24 years  \
# 0                                           NaN
# 1                                       292,361
# 2                                          7.4%
#
#   SEX AND AGE!!Total population!!25 to 34 years  \
# 0                                           NaN
# 1                                       723,858
# 2                                         18.2%
#
#   SEX AND AGE!!Total population!!35 to 44 years  \
# 0                                           NaN
# 1                                       571,032
# 2                                         14.4%
#
#   SEX AND AGE!!Total population!!45 to 54 years  \
# 0                                           NaN
# 1                                       516,798
# 2                                         13.0%
#
#   SEX AND AGE!!Total population!!55 to 59 years  \
# 0                                           NaN
# 1                                       237,072
# 2                                          6.0%
#
#   SEX AND AGE!!Total population!!60 to 64 years  \
# 0                                           NaN
# 1                                       208,031
# 2                                          5.2%
#
#   SEX AND AGE!!Total population!!65 to 74 years  \
# 0                                           NaN
# 1                                       290,863
# 2                                          7.3%
#
#   SEX AND AGE!!Total population!!75 to 84 years  \
# 0                                           NaN
# 1                                       143,939
# 2                                          3.6%
#
#   SEX AND AGE!!Total population!!85 years and over  \
# 0                                              NaN
# 1                                           75,985
# 2                                             1.9%
#
#   SEX AND AGE!!Total population!!Median age (years)
# 0                                               NaN
# 1                                              35.9
# 2                                               (X)

# %%
la_age_df = la_age_df.drop(columns=['SEX AND AGE'])
la_age_df.head()
# Out:
#                Label (Grouping) SEX AND AGE!!Total population  \
# 0  Los Angeles city, California                           NaN
# 1                      Estimate                     3,973,278
# 2                       Percent                     3,973,278
#
#   SEX AND AGE!!Total population!!Under 5 years  \
# 0                                          NaN
# 1                                      226,227
# 2                                         5.7%
#
#   SEX AND AGE!!Total population!!5 to 9 years  \
# 0                                         NaN
# 1                                     224,155
# 2                                        5.6%
#
#   SEX AND AGE!!Total population!!10 to 14 years  \
# 0                                           NaN
# 1                                       225,304
# 2                                          5.7%
#
#   SEX AND AGE!!Total population!!15 to 19 years  \
# 0                                           NaN
# 1                                       237,653
# 2                                          6.0%
#
#   SEX AND AGE!!Total population!!20 to 24 years  \
# 0                                           NaN
# 1                                       292,361
# 2                                          7.4%
#
#   SEX AND AGE!!Total population!!25 to 34 years  \
# 0                                           NaN
# 1                                       723,858
# 2                                         18.2%
#
#   SEX AND AGE!!Total population!!35 to 44 years  \
# 0                                           NaN
# 1                                       571,032
# 2                                         14.4%
#
#   SEX AND AGE!!Total population!!45 to 54 years  \
# 0                                           NaN
# 1                                       516,798
# 2                                         13.0%
#
#   SEX AND AGE!!Total population!!55 to 59 years  \
# 0                                           NaN
# 1                                       237,072
# 2                                          6.0%
#
#   SEX AND AGE!!Total population!!60 to 64 years  \
# 0                                           NaN
# 1                                       208,031
# 2                                          5.2%
#
#   SEX AND AGE!!Total population!!65 to 74 years  \
# 0                                           NaN
# 1                                       290,863
# 2                                          7.3%
#
#   SEX AND AGE!!Total population!!75 to 84 years  \
# 0                                           NaN
# 1                                       143,939
# 2                                          3.6%
#
#   SEX AND AGE!!Total population!!85 years and over  \
# 0                                              NaN
# 1                                           75,985
# 2                                             1.9%
#
#   SEX AND AGE!!Total population!!Median age (years)
# 0                                               NaN
# 1                                              35.9
# 2                                               (X)

# %%
# Rename columns for clarity
la_age_df.columns = ['',
  'Total Population',
  'Under 5',
  '5 to 9',
  '10 to 14',
  '15 to 19',
  '20 to 24',
  '25 to 34',
  '35 to 44',
  '45 to 54',
  '55 to 59',
  '60 to 64',
  '65 to 74',
  '75 to 84',
  '85 and Over',
  'Median Age'
]

la_age_df.head()
# Out:
#                                 Total Population  Under 5   5 to 9 10 to 14  \
# 0  Los Angeles city, California              NaN      NaN      NaN      NaN
# 1                      Estimate        3,973,278  226,227  224,155  225,304
# 2                       Percent        3,973,278     5.7%     5.6%     5.7%
#
#   15 to 19 20 to 24 25 to 34 35 to 44 45 to 54 55 to 59 60 to 64 65 to 74  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1  237,653  292,361  723,858  571,032  516,798  237,072  208,031  290,863
# 2     6.0%     7.4%    18.2%    14.4%    13.0%     6.0%     5.2%     7.3%
#
#   75 to 84 85 and Over Median Age
# 0      NaN         NaN        NaN
# 1  143,939      75,985       35.9
# 2     3.6%        1.9%        (X)

# %%
# Drop NaN values
la_age_df = la_age_df.dropna()
la_age_df.head()
# Out:
#                 Total Population  Under 5   5 to 9 10 to 14 15 to 19 20 to 24  \
# 1      Estimate        3,973,278  226,227  224,155  225,304  237,653  292,361
# 2       Percent        3,973,278     5.7%     5.6%     5.7%     6.0%     7.4%
#
#   25 to 34 35 to 44 45 to 54 55 to 59 60 to 64 65 to 74 75 to 84 85 and Over  \
# 1  723,858  571,032  516,798  237,072  208,031  290,863  143,939      75,985
# 2    18.2%    14.4%    13.0%     6.0%     5.2%     7.3%     3.6%        1.9%
#
#   Median Age
# 1       35.9
# 2        (X)

# %%
# Save the cleaned DataFrame to a new CSV file
la_age_df.to_csv('../los_angeles_data/la_cleaned_csv/cleaned_la_age.csv', index=False)

# %% [markdown]
# #### Racial Demographics (Table DP05)

# %%
# Import csv file for race
la_race_data = "..\los_angeles_data\la_raw_csv\la_race.csv"

# Read the CSV file into a DataFrame
la_race_df = pd.read_csv(la_race_data)
la_race_df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\3814218149.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_race_data = "..\los_angeles_data\la_raw_csv\la_race.csv"
#                Label (Grouping)  \
# 0  Los Angeles city, California
# 1                      Estimate
# 2                       Percent
#
#    Race alone or in combination with one or more other races  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   Race alone or in combination with one or more other races!!Total population  \
# 0                                                NaN
# 1                                          3,973,278
# 2                                          3,973,278
#
#   Race alone or in combination with one or more other races!!Total population!!White  \
# 0                                                NaN
# 1                                          2,187,180
# 2                                              55.0%
#
#   Race alone or in combination with one or more other races!!Total population!!Black or African American  \
# 0                                                NaN
# 1                                            401,039
# 2                                              10.1%
#
#   Race alone or in combination with one or more other races!!Total population!!American Indian and Alaska Native  \
# 0                                                NaN
# 1                                             62,817
# 2                                               1.6%
#
#   Race alone or in combination with one or more other races!!Total population!!Asian  \
# 0                                                NaN
# 1                                            541,935
# 2                                              13.6%
#
#   Race alone or in combination with one or more other races!!Total population!!Native Hawaiian and Other Pacific Islander  \
# 0                                                NaN
# 1                                             18,525
# 2                                               0.5%
#
#   Race alone or in combination with one or more other races!!Total population!!Some other race
# 0                                                NaN
# 1                                          1,058,349
# 2                                              26.6%

# %%
# Rename columns to remove 'Race alone or in combination with one or more other races!!Total population!!' from the column names
la_race_df.columns = la_race_df.columns.str.replace('Race alone or in combination with one or more other races!!Total population!!', '')
la_race_df.head()
# Out:
#                Label (Grouping)  \
# 0  Los Angeles city, California
# 1                      Estimate
# 2                       Percent
#
#    Race alone or in combination with one or more other races  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   Race alone or in combination with one or more other races!!Total population  \
# 0                                                NaN
# 1                                          3,973,278
# 2                                          3,973,278
#
#        White Black or African American American Indian and Alaska Native  \
# 0        NaN                       NaN                               NaN
# 1  2,187,180                   401,039                            62,817
# 2      55.0%                     10.1%                              1.6%
#
#      Asian Native Hawaiian and Other Pacific Islander Some other race
# 0      NaN                                        NaN             NaN
# 1  541,935                                     18,525       1,058,349
# 2    13.6%                                       0.5%           26.6%

# %%
la_race_df = la_race_df.drop(columns=['Race alone or in combination with one or more other races'])
la_race_df.head()
# Out:
#                Label (Grouping)  \
# 0  Los Angeles city, California
# 1                      Estimate
# 2                       Percent
#
#   Race alone or in combination with one or more other races!!Total population  \
# 0                                                NaN
# 1                                          3,973,278
# 2                                          3,973,278
#
#        White Black or African American American Indian and Alaska Native  \
# 0        NaN                       NaN                               NaN
# 1  2,187,180                   401,039                            62,817
# 2      55.0%                     10.1%                              1.6%
#
#      Asian Native Hawaiian and Other Pacific Islander Some other race
# 0      NaN                                        NaN             NaN
# 1  541,935                                     18,525       1,058,349
# 2    13.6%                                       0.5%           26.6%

# %%
# Rename columns for clarity 
la_race_df.columns = ['', 
                       'Total Population',
                           'White', 
                           'Black or African American', 
                           'American Indian and Alaska Native', 
                           'Asian', 
                           'Native Hawaiian and Other Pacific Islander', 
                           'Other']

# Display
la_race_df.head()
# Out:
#                                 Total Population      White  \
# 0  Los Angeles city, California              NaN        NaN
# 1                      Estimate        3,973,278  2,187,180
# 2                       Percent        3,973,278      55.0%
#
#   Black or African American American Indian and Alaska Native    Asian  \
# 0                       NaN                               NaN      NaN
# 1                   401,039                            62,817  541,935
# 2                     10.1%                              1.6%    13.6%
#
#   Native Hawaiian and Other Pacific Islander      Other
# 0                                        NaN        NaN
# 1                                     18,525  1,058,349
# 2                                       0.5%      26.6%

# %%
# Drop NaN values
la_race_df = la_race_df.dropna()

# %%
# Save as new CSV file
la_race_df.to_csv('../los_angeles_data/la_cleaned_csv/cleaned_la_race.csv', index=False)

# %% [markdown]
# #### Education Level (Table S1501)

# %%
# Import csv file for Texas edu level 
la_edu_data = "..\los_angeles_data\la_raw_csv\la_edu_lvl.csv"

# Read the CSV file into a DataFrame
la_edu_df = pd.read_csv(la_edu_data)
la_edu_df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\2405539290.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_edu_data = "..\los_angeles_data\la_raw_csv\la_edu_lvl.csv"
#                                      Label (Grouping)  \
# 0                       AGE BY EDUCATIONAL ATTAINMENT
# 1                           Population 18 to 24 years
# 2                      Less than high school graduate
# 3           High school graduate (includes equival...
# 4                  Some college or associate's degree
# ..                                                ...
# 63                     Less than high school graduate
# 64          High school graduate (includes equival...
# 65                 Some college or associate's degree
# 66                                  Bachelor's degree
# 67                    Graduate or professional degree
#
#    California!!Total!!Estimate California!!Total!!Margin of Error  \
# 0                          NaN                                NaN
# 1                    3,724,239                             ±1,093
# 2                      383,097                             ±4,474
# 3                    1,164,734                             ±7,650
# 4                    1,749,440                             ±9,230
# ..                         ...                                ...
# 63                      25,253                                ±92
# 64                      32,560                               ±171
# 65                      40,683                                ±99
# 66                      64,554                               ±307
# 67                      91,622                               ±344
#
#    California!!Percent!!Estimate California!!Percent!!Margin of Error  \
# 0                            NaN                                  NaN
# 1                            (X)                                  (X)
# 2                          10.3%                                 ±0.1
# 3                          31.3%                                 ±0.2
# 4                          47.0%                                 ±0.2
# ..                           ...                                  ...
# 63                           (X)                                  (X)
# 64                           (X)                                  (X)
# 65                           (X)                                  (X)
# 66                           (X)                                  (X)
# 67                           (X)                                  (X)
#
#    California!!Male!!Estimate California!!Male!!Margin of Error  \
# 0                         NaN                               NaN
# 1                   1,914,100                              ±755
# 2                     229,054                            ±3,239
# 3                     657,609                            ±5,782
# 4                     845,388                            ±6,628
# ..                        ...                               ...
# 63                     29,734                              ±226
# 64                     38,059                              ±283
# 65                     48,230                              ±274
# 66                     76,714                              ±447
# 67                    108,329                              ±621
#
#    California!!Percent Male!!Estimate  \
# 0                                 NaN
# 1                                 (X)
# 2                               12.0%
# 3                               34.4%
# 4                               44.2%
# ..                                ...
# 63                                (X)
# 64                                (X)
# 65                                (X)
# 66                                (X)
# 67                                (X)
#
#    California!!Percent Male!!Margin of Error California!!Female!!Estimate  \
# 0                                        NaN                          NaN
# 1                                        (X)                    1,810,139
# 2                                       ±0.2                      154,043
# 3                                       ±0.3                      507,125
# 4                                       ±0.3                      904,052
# ..                                       ...                          ...
# 63                                       (X)                       19,064
# 64                                       (X)                       26,830
# 65                                       (X)                       34,162
# 66                                       (X)                       54,297
# 67                                       (X)                       77,953
#
#     ... Los Angeles city, California!!Percent!!Estimate  \
# 0   ...                                             NaN
# 1   ...                                             (X)
# 2   ...                                           11.8%
# 3   ...                                           25.6%
# 4   ...                                           48.4%
# ..  ...                                             ...
# 63  ...                                             (X)
# 64  ...                                             (X)
# 65  ...                                             (X)
# 66  ...                                             (X)
# 67  ...                                             (X)
#
#    Los Angeles city, California!!Percent!!Margin of Error  \
# 0                                                 NaN
# 1                                                 (X)
# 2                                                ±0.4
# 3                                                ±0.6
# 4                                                ±0.8
# ..                                                ...
# 63                                                (X)
# 64                                                (X)
# 65                                                (X)
# 66                                                (X)
# 67                                                (X)
#
#    Los Angeles city, California!!Male!!Estimate  \
# 0                                           NaN
# 1                                       197,761
# 2                                        27,942
# 3                                        56,242
# 4                                        90,716
# ..                                          ...
# 63                                       25,900
# 64                                       32,252
# 65                                       40,512
# 66                                       63,120
# 67                                       90,799
#
#    Los Angeles city, California!!Male!!Margin of Error  \
# 0                                                 NaN
# 1                                              ±2,716
# 2                                              ±1,308
# 3                                              ±1,667
# 4                                              ±2,124
# ..                                                ...
# 63                                               ±276
# 64                                               ±340
# 65                                               ±597
# 66                                               ±952
# 67                                             ±2,072
#
#    Los Angeles city, California!!Percent Male!!Estimate  \
# 0                                                 NaN
# 1                                                 (X)
# 2                                               14.1%
# 3                                               28.4%
# 4                                               45.9%
# ..                                                ...
# 63                                                (X)
# 64                                                (X)
# 65                                                (X)
# 66                                                (X)
# 67                                                (X)
#
#    Los Angeles city, California!!Percent Male!!Margin of Error  \
# 0                                                 NaN
# 1                                                 (X)
# 2                                                ±0.6
# 3                                                ±0.7
# 4                                                ±1.0
# ..                                                ...
# 63                                                (X)
# 64                                                (X)
# 65                                                (X)
# 66                                                (X)
# 67                                                (X)
#
#    Los Angeles city, California!!Female!!Estimate  \
# 0                                             NaN
# 1                                         198,490
# 2                                          18,789
# 3                                          45,313
# 4                                         101,038
# ..                                            ...
# 63                                         18,044
# 64                                         25,540
# 65                                         32,433
# 66                                         51,016
# 67                                         70,862
#
#    Los Angeles city, California!!Female!!Margin of Error  \
# 0                                                 NaN
# 1                                              ±2,968
# 2                                              ±1,094
# 3                                              ±1,764
# 4                                              ±2,521
# ..                                                ...
# 63                                               ±337
# 64                                               ±457
# 65                                               ±456
# 66                                               ±618
# 67                                             ±1,317
#
#    Los Angeles city, California!!Percent Female!!Estimate  \
# 0                                                 NaN
# 1                                                 (X)
# 2                                                9.5%
# 3                                               22.8%
# 4                                               50.9%
# ..                                                ...
# 63                                                (X)
# 64                                                (X)
# 65                                                (X)
# 66                                                (X)
# 67                                                (X)
#
#    Los Angeles city, California!!Percent Female!!Margin of Error
# 0                                                 NaN
# 1                                                 (X)
# 2                                                ±0.5
# 3                                                ±0.9
# 4                                                ±1.0
# ..                                                ...
# 63                                                (X)
# 64                                                (X)
# 65                                                (X)
# 66                                                (X)
# 67                                                (X)
#
# [68 rows x 25 columns]

# %%
# Source data (filter only what is needed out of dataset)
la_edu_df = la_edu_df.iloc[:28]

#drop all columns with "margin of error" in the column name
la_edu_df = la_edu_df.loc[:, ~la_edu_df.columns.str.contains('Margin of Error')]

#drop all columns with percent in the column name
la_edu_df = la_edu_df.loc[:, ~la_edu_df.columns.str.contains('Percent')]

#drop columns that begin with california
la_edu_df = la_edu_df.loc[:, ~la_edu_df.columns.str.startswith('California')]

la_edu_df.head()
# Out:
#                                     Label (Grouping)  \
# 0                      AGE BY EDUCATIONAL ATTAINMENT
# 1                          Population 18 to 24 years
# 2                     Less than high school graduate
# 3          High school graduate (includes equival...
# 4                 Some college or associate's degree
#
#   Los Angeles city, California!!Total!!Estimate  \
# 0                                           NaN
# 1                                       396,251
# 2                                        46,731
# 3                                       101,555
# 4                                       191,754
#
#   Los Angeles city, California!!Male!!Estimate  \
# 0                                          NaN
# 1                                      197,761
# 2                                       27,942
# 3                                       56,242
# 4                                       90,716
#
#   Los Angeles city, California!!Female!!Estimate
# 0                                            NaN
# 1                                        198,490
# 2                                         18,789
# 3                                         45,313
# 4                                        101,038

# %%
# Rename columns for clarity 
la_edu_df.columns = ['Age by Educational Attainment',
                          'Total', 
                            'Male',
                            'Female']
la_edu_df.head()
# Out:
#                        Age by Educational Attainment    Total     Male  \
# 0                      AGE BY EDUCATIONAL ATTAINMENT      NaN      NaN
# 1                          Population 18 to 24 years  396,251  197,761
# 2                     Less than high school graduate   46,731   27,942
# 3          High school graduate (includes equival...  101,555   56,242
# 4                 Some college or associate's degree  191,754   90,716
#
#     Female
# 0      NaN
# 1  198,490
# 2   18,789
# 3   45,313
# 4  101,038

# %%
# Drop NaN values
la_edu_df = la_edu_df.dropna()

# %%
# save as new csv file with cleaned data
la_edu_df.to_csv('..\los_angeles_data\la_cleaned_csv\cleaned_la_edu_lvl.csv', index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\2826431234.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_edu_df.to_csv('..\los_angeles_data\la_cleaned_csv\cleaned_la_edu_lvl.csv', index=False)

# %% [markdown]
# ## Economic Metric
#
# **Measuring**: Median lasehold Income, Unemployment Rate, Poverty Rate.
#
# Data for this section was pulled from the la 2020 Census Database using various coded tables:
# * Median lasehold Income: Table S1901
# * Unemployment Rate: Table S2301
# * Poverty Rate: S1501 - WE ARE CUTTING

# %% [markdown]
# ##### Median lasehold Income (Table S1901)

# %%
# Import csv file from Median lasehold Income
la_income_data = '..\los_angeles_data\la_raw_csv\LA_med_household_income.csv'

# Read the CSV file into a DataFrame
la_income_df = pd.read_csv(la_income_data)
la_income_df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\2988956272.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_income_data = '..\los_angeles_data\la_raw_csv\LA_med_household_income.csv'
#          Label (Grouping) California!!Households!!Estimate  \
# 0                   Total                       13,103,114
# 1       Less than $10,000                             4.7%
# 2      $10,000 to $14,999                             3.9%
# 3      $15,000 to $24,999                             6.9%
# 4      $25,000 to $34,999                             7.1%
#
#   California!!Households!!Margin of Error California!!Families!!Estimate  \
# 0                                 ±18,542                      8,986,666
# 1                                    ±0.1                           3.1%
# 2                                    ±0.1                           2.1%
# 3                                    ±0.1                           5.6%
# 4                                    ±0.1                           6.4%
#
#   California!!Families!!Margin of Error  \
# 0                               ±23,960
# 1                                  ±0.1
# 2                                  ±0.1
# 3                                  ±0.1
# 4                                  ±0.1
#
#   California!!Married-couple families!!Estimate  \
# 0                                     6,510,580
# 1                                          1.4%
# 2                                          1.1%
# 3                                          3.8%
# 4                                          4.8%
#
#   California!!Married-couple families!!Margin of Error  \
# 0                                            ±28,316
# 1                                               ±0.1
# 2                                               ±0.1
# 3                                               ±0.1
# 4                                               ±0.1
#
#   California!!Nonfamily households!!Estimate  \
# 0                                  4,116,448
# 1                                       9.5%
# 2                                       8.4%
# 3                                      10.9%
# 4                                       9.3%
#
#   California!!Nonfamily households!!Margin of Error  \
# 0                                           ±12,837
# 1                                              ±0.1
# 2                                              ±0.1
# 3                                              ±0.1
# 4                                              ±0.1
#
#   Los Angeles city, California!!Households!!Estimate  \
# 0                                          1,402,522
# 1                                               6.6%
# 2                                               5.5%
# 3                                               8.6%
# 4                                               8.1%
#
#   Los Angeles city, California!!Households!!Margin of Error  \
# 0                                             ±4,385
# 1                                               ±0.2
# 2                                               ±0.2
# 3                                               ±0.2
# 4                                               ±0.2
#
#   Los Angeles city, California!!Families!!Estimate  \
# 0                                          830,131
# 1                                             4.0%
# 2                                             2.9%
# 3                                             8.2%
# 4                                             8.1%
#
#   Los Angeles city, California!!Families!!Margin of Error  \
# 0                                             ±4,327
# 1                                               ±0.1
# 2                                               ±0.1
# 3                                               ±0.2
# 4                                               ±0.2
#
#   Los Angeles city, California!!Married-couple families!!Estimate  \
# 0                                            542,563
# 1                                               1.7%
# 2                                               1.7%
# 3                                               6.2%
# 4                                               6.3%
#
#   Los Angeles city, California!!Married-couple families!!Margin of Error  \
# 0                                             ±4,178
# 1                                               ±0.1
# 2                                               ±0.1
# 3                                               ±0.3
# 4                                               ±0.2
#
#   Los Angeles city, California!!Nonfamily households!!Estimate  \
# 0                                            572,391
# 1                                              11.4%
# 2                                               9.6%
# 3                                              10.1%
# 4                                               8.6%
#
#   Los Angeles city, California!!Nonfamily households!!Margin of Error
# 0                                             ±5,787
# 1                                               ±0.3
# 2                                               ±0.3
# 3                                               ±0.3
# 4                                               ±0.3

# %%
# Droping unnecessary rows and columns
la_income_df = la_income_df.iloc[:13]

#drop all columns with "margin of error" in the column name
la_income_df = la_income_df.loc[:, ~la_income_df.columns.str.contains('Margin of Error')]

#drop all columns with percent in the column name
la_income_df = la_income_df.loc[:, ~la_income_df.columns.str.contains('Percent')]

#drop columns that begin with california
la_income_df = la_income_df.loc[:, ~la_income_df.columns.str.startswith('California')]

la_income_df.head()
# Out:
#          Label (Grouping) Los Angeles city, California!!Households!!Estimate  \
# 0                   Total                                          1,402,522
# 1       Less than $10,000                                               6.6%
# 2      $10,000 to $14,999                                               5.5%
# 3      $15,000 to $24,999                                               8.6%
# 4      $25,000 to $34,999                                               8.1%
#
#   Los Angeles city, California!!Families!!Estimate  \
# 0                                          830,131
# 1                                             4.0%
# 2                                             2.9%
# 3                                             8.2%
# 4                                             8.1%
#
#   Los Angeles city, California!!Married-couple families!!Estimate  \
# 0                                            542,563
# 1                                               1.7%
# 2                                               1.7%
# 3                                               6.2%
# 4                                               6.3%
#
#   Los Angeles city, California!!Nonfamily households!!Estimate
# 0                                            572,391
# 1                                              11.4%
# 2                                               9.6%
# 3                                              10.1%
# 4                                               8.6%

# %%
# Rename columns for clarity
la_income_df.columns = ['',
                             'lasehold', 
                              'Families', 
                              'Married-couple laseholds', 
                              'Nonfamily laseholds']
la_income_df.head()
# Out:
#                             lasehold Families Married-couple laseholds  \
# 0                   Total  1,402,522  830,131                  542,563
# 1       Less than $10,000       6.6%     4.0%                     1.7%
# 2      $10,000 to $14,999       5.5%     2.9%                     1.7%
# 3      $15,000 to $24,999       8.6%     8.2%                     6.2%
# 4      $25,000 to $34,999       8.1%     8.1%                     6.3%
#
#   Nonfamily laseholds
# 0             572,391
# 1               11.4%
# 2                9.6%
# 3               10.1%
# 4                8.6%

# %%
# Save as new csv file with cleaned data
la_income_df.to_csv('..\los_angeles_data\la_cleaned_csv\cleaned_la_med_household_income.csv', index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\97048104.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_income_df.to_csv('..\los_angeles_data\la_cleaned_csv\cleaned_la_med_household_income.csv', index=False)

# %% [markdown]
# ##### Unemployment Rate (Table S2301)

# %%
# Import csv file from unemployment rate
la_unemployment_data = '..\los_angeles_data\la_cleaned_csv\cleaned_la_unemployment_rate.csv'

# Read the CSV file into a DataFrame
la_unemployment_df = pd.read_csv(la_unemployment_data)
la_unemployment_df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\571843109.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_unemployment_data = '..\los_angeles_data\la_cleaned_csv\cleaned_la_unemployment_rate.csv'
#                       Age Group      Total Labor Force Participation  \
# 0  Population 16 years and over  3,254,012                     66.5%
# 1                16 to 19 years    194,073                     25.7%
# 2                20 to 24 years    292,361                     69.9%
# 3                25 to 29 years    372,648                     84.2%
# 4                30 to 34 years    351,210                     84.4%
#
#   Employment Population Ratio Unemployment Rate
# 0                       61.9%              6.9%
# 1                       19.7%             23.2%
# 2                       61.9%             11.3%
# 3                       78.1%              7.2%
# 4                       79.2%              6.0%

# %%
# Filter the DataFrame to only include rows 0-11
la_unemployment_df = la_unemployment_df.iloc[0:12]

#drop columns that begin with california
la_unemployment_df = la_unemployment_df.loc[:, ~la_unemployment_df.columns.str.startswith('California')]

# Display the filtered DataFrame
la_unemployment_df.head()
# Out:
#                       Age Group      Total Labor Force Participation  \
# 0  Population 16 years and over  3,254,012                     66.5%
# 1                16 to 19 years    194,073                     25.7%
# 2                20 to 24 years    292,361                     69.9%
# 3                25 to 29 years    372,648                     84.2%
# 4                30 to 34 years    351,210                     84.4%
#
#   Employment Population Ratio Unemployment Rate
# 0                       61.9%              6.9%
# 1                       19.7%             23.2%
# 2                       61.9%             11.3%
# 3                       78.1%              7.2%
# 4                       79.2%              6.0%

# %%
# Rename columns for clarity
la_unemployment_df.columns = ['Age Group', 
                                   'Total', 
                                   'Labor Force Participation', 
                                   'Employment Population Ratio', 
                                   'Unemployment Rate']
la_unemployment_df.head()
# Out:
#                       Age Group      Total Labor Force Participation  \
# 0  Population 16 years and over  3,254,012                     66.5%
# 1                16 to 19 years    194,073                     25.7%
# 2                20 to 24 years    292,361                     69.9%
# 3                25 to 29 years    372,648                     84.2%
# 4                30 to 34 years    351,210                     84.4%
#
#   Employment Population Ratio Unemployment Rate
# 0                       61.9%              6.9%
# 1                       19.7%             23.2%
# 2                       61.9%             11.3%
# 3                       78.1%              7.2%
# 4                       79.2%              6.0%

# %%
# Drop any NaN values
la_unemployment_df = la_unemployment_df.dropna()

# %%
# Save the cleaned DataFrame to a new CSV file
la_unemployment_df.to_csv('..\los_angeles_data\la_cleaned_csv\cleaned_la_unemployment_rate.csv', index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\2065279977.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_unemployment_df.to_csv('..\los_angeles_data\la_cleaned_csv\cleaned_la_unemployment_rate.csv', index=False)

# %% [markdown]
# ## lasing Metric
#
# **Measuring**: Median Home Price, Median Rent, Homeownership Rate
#
# Data for this section was pulled from the la 2020 Census Database using the same table code from the American Community Survey by the U.S. Census Bureau (ACS).
# * Median Rent: Table DP04

# %% [markdown]
# #### Median Rent (DP04)

# %%
# Import csv file 
la_rent_data = '..\los_angeles_data\la_raw_csv\la_rent.csv'

# Read the CSV file into a DataFrame
la_rent_df = pd.read_csv(la_rent_data)
la_rent_df.head()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\3965131750.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_rent_data = '..\los_angeles_data\la_raw_csv\la_rent.csv'
#                Label (Grouping)  GROSS RENT  \
# 0  Los Angeles city, California         NaN
# 1                      Estimate         NaN
# 2                       Percent         NaN
#
#   GROSS RENT!!Occupied units paying rent  \
# 0                                    NaN
# 1                                865,877
# 2                                865,877
#
#   GROSS RENT!!Occupied units paying rent!!Less than $500  \
# 0                                                NaN
# 1                                             44,630
# 2                                               5.2%
#
#   GROSS RENT!!Occupied units paying rent!!$500 to $999  \
# 0                                                NaN
# 1                                            119,637
# 2                                              13.8%
#
#   GROSS RENT!!Occupied units paying rent!!$1,000 to $1,499  \
# 0                                                NaN
# 1                                            259,348
# 2                                              30.0%
#
#   GROSS RENT!!Occupied units paying rent!!$1,500 to $1,999  \
# 0                                                NaN
# 1                                            203,998
# 2                                              23.6%
#
#   GROSS RENT!!Occupied units paying rent!!$2,000 to $2,499  \
# 0                                                NaN
# 1                                            116,140
# 2                                              13.4%
#
#   GROSS RENT!!Occupied units paying rent!!$2,500 to $2,999  \
# 0                                                NaN
# 1                                             60,439
# 2                                               7.0%
#
#   GROSS RENT!!Occupied units paying rent!!$3,000 or more  \
# 0                                                NaN
# 1                                             61,685
# 2                                               7.1%
#
#   GROSS RENT!!Occupied units paying rent!!Median (dollars)  \
# 0                                                NaN
# 1                                              1,523
# 2                                                (X)
#
#   GROSS RENT!!Occupied units paying rent!!No rent paid
# 0                                                NaN
# 1                                             18,299
# 2                                                (X)

# %%
# Rename columns for clarity
la_rent_df.columns = ['',
                             'Total lasing Units',
                             'Occupied lasing Units Paying Rent',
                             'Less than $500',
                             '$500 to $999',
                             '$1,000 to $1,499',
                             '$1,500 to $1,999',
                             '$2,000 to $2,499',
                             '$2,500 to $2,999',
                             '$3,000 or more',
                             'Median Rent Price',
                             'No rent paid'
]
la_rent_df.head()
# Out:
#                                  Total lasing Units  \
# 0  Los Angeles city, California                 NaN
# 1                      Estimate                 NaN
# 2                       Percent                 NaN
#
#   Occupied lasing Units Paying Rent Less than $500 $500 to $999  \
# 0                               NaN            NaN          NaN
# 1                           865,877         44,630      119,637
# 2                           865,877           5.2%        13.8%
#
#   $1,000 to $1,499 $1,500 to $1,999 $2,000 to $2,499 $2,500 to $2,999  \
# 0              NaN              NaN              NaN              NaN
# 1          259,348          203,998          116,140           60,439
# 2            30.0%            23.6%            13.4%             7.0%
#
#   $3,000 or more Median Rent Price No rent paid
# 0            NaN               NaN          NaN
# 1         61,685             1,523       18,299
# 2           7.1%               (X)          (X)

# %%
# Drop NaN values
la_rent_df = la_rent_df.dropna()

# %%
# Save the cleaned DataFrame to a new CSV file
la_rent_df.to_csv('..\los_angeles_data\la_cleaned_csv\cleaned_la_rent.csv', index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\610339767.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_rent_df.to_csv('..\los_angeles_data\la_cleaned_csv\cleaned_la_rent.csv', index=False)

# %% [markdown]
# ## Quality of Life Metric
#
# **Measuring**: Commute Time
#
# Data was pulled from the Census Database using the following survey by ASC in 2020.
# * Commute Time: Table S0801

# %%
# Import csv file from commute time
la_commute_data = '..\los_angeles_data\la_raw_csv\LA_commute_time.csv'

# Read the CSV file into a DataFrame
la_commute_df = pd.read_csv(la_commute_data)
la_commute_df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\895386742.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_commute_data = '..\los_angeles_data\la_raw_csv\LA_commute_time.csv'
#                        Label (Grouping) California!!Total!!Estimate  \
# 0             Workers 16 years and over                  18,239,892
# 1       MEANS OF TRANSPORTATION TO WORK                         NaN
# 2                    Car, truck, or van                       82.0%
# 3                           Drove alone                       72.1%
# 4                             Carpooled                       10.0%
# ..                                  ...                         ...
# 58            Private vehicle occupancy                       15.3%
# 59                        Place of work                       17.8%
# 60      Time of departure to go to work                       25.0%
# 61                  Travel time to work                       19.1%
# 62                   Vehicles available                        1.4%
#
#    California!!Total!!Margin of Error California!!Male!!Estimate  \
# 0                             ±23,587                  9,925,774
# 1                                 NaN                        NaN
# 2                                ±0.1                      82.7%
# 3                                ±0.1                      73.1%
# 4                                ±0.1                       9.6%
# ..                                ...                        ...
# 58                                (X)                        (X)
# 59                                (X)                        (X)
# 60                                (X)                        (X)
# 61                                (X)                        (X)
# 62                                (X)                        (X)
#
#    California!!Male!!Margin of Error California!!Female!!Estimate  \
# 0                            ±14,377                    8,314,118
# 1                                NaN                          NaN
# 2                               ±0.1                        81.2%
# 3                               ±0.1                        70.9%
# 4                               ±0.1                        10.3%
# ..                               ...                          ...
# 58                               (X)                          (X)
# 59                               (X)                          (X)
# 60                               (X)                          (X)
# 61                               (X)                          (X)
# 62                               (X)                          (X)
#
#    California!!Female!!Margin of Error  \
# 0                              ±19,722
# 1                                  NaN
# 2                                 ±0.1
# 3                                 ±0.1
# 4                                 ±0.1
# ..                                 ...
# 58                                 (X)
# 59                                 (X)
# 60                                 (X)
# 61                                 (X)
# 62                                 (X)
#
#    Los Angeles city, California!!Total!!Estimate  \
# 0                                      1,956,957
# 1                                            NaN
# 2                                          76.6%
# 3                                          67.7%
# 4                                           8.9%
# ..                                           ...
# 58                                         16.0%
# 59                                         18.1%
# 60                                         25.8%
# 61                                         21.8%
# 62                                          1.5%
#
#    Los Angeles city, California!!Total!!Margin of Error  \
# 0                                              ±6,935
# 1                                                 NaN
# 2                                                ±0.3
# 3                                                ±0.3
# 4                                                ±0.2
# ..                                                ...
# 58                                                (X)
# 59                                                (X)
# 60                                                (X)
# 61                                                (X)
# 62                                                (X)
#
#    Los Angeles city, California!!Male!!Estimate  \
# 0                                     1,058,847
# 1                                           NaN
# 2                                         77.8%
# 3                                         69.2%
# 4                                          8.5%
# ..                                          ...
# 58                                          (X)
# 59                                          (X)
# 60                                          (X)
# 61                                          (X)
# 62                                          (X)
#
#    Los Angeles city, California!!Male!!Margin of Error  \
# 0                                              ±5,319
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.4
# 4                                                ±0.2
# ..                                                ...
# 58                                                (X)
# 59                                                (X)
# 60                                                (X)
# 61                                                (X)
# 62                                                (X)
#
#    Los Angeles city, California!!Female!!Estimate  \
# 0                                         898,110
# 1                                             NaN
# 2                                           75.2%
# 3                                           65.9%
# 4                                            9.4%
# ..                                            ...
# 58                                            (X)
# 59                                            (X)
# 60                                            (X)
# 61                                            (X)
# 62                                            (X)
#
#    Los Angeles city, California!!Female!!Margin of Error
# 0                                              ±4,858
# 1                                                 NaN
# 2                                                ±0.4
# 3                                                ±0.4
# 4                                                ±0.2
# ..                                                ...
# 58                                                (X)
# 59                                                (X)
# 60                                                (X)
# 61                                                (X)
# 62                                                (X)
#
# [63 rows x 13 columns]

# %%
la_commute_df = la_commute_df.iloc[:14]
#drop all columns with "margin of error" in the column name
la_commute_df = la_commute_df.loc[:, ~la_commute_df.columns.str.contains('Margin of Error')]

#drop all columns with percent in the column name
la_commute_df = la_commute_df.loc[:, ~la_commute_df.columns.str.contains('Percent')]

#drop columns that begin with california
la_commute_df = la_commute_df.loc[:, ~la_commute_df.columns.str.startswith('California')]

la_commute_df.head()
# Out:
#                       Label (Grouping)  \
# 0            Workers 16 years and over
# 1      MEANS OF TRANSPORTATION TO WORK
# 2                   Car, truck, or van
# 3                          Drove alone
# 4                            Carpooled
#
#   Los Angeles city, California!!Total!!Estimate  \
# 0                                     1,956,957
# 1                                           NaN
# 2                                         76.6%
# 3                                         67.7%
# 4                                          8.9%
#
#   Los Angeles city, California!!Male!!Estimate  \
# 0                                    1,058,847
# 1                                          NaN
# 2                                        77.8%
# 3                                        69.2%
# 4                                         8.5%
#
#   Los Angeles city, California!!Female!!Estimate
# 0                                        898,110
# 1                                            NaN
# 2                                          75.2%
# 3                                          65.9%
# 4                                           9.4%

# %%
# Rewrite for clarity 
la_commute_df.columns = ['',
                              'Total Estimate',
                              'Male',
                              'Female'
                              ]
la_commute_df.head()
# Out:
#                                        Total Estimate       Male   Female
# 0            Workers 16 years and over      1,956,957  1,058,847  898,110
# 1      MEANS OF TRANSPORTATION TO WORK            NaN        NaN      NaN
# 2                   Car, truck, or van          76.6%      77.8%    75.2%
# 3                          Drove alone          67.7%      69.2%    65.9%
# 4                            Carpooled           8.9%       8.5%     9.4%

# %%
# Drop NaN values
la_commute_df = la_commute_df.dropna()

# %%
# Save as new csv file with cleaned data
la_commute_df.to_csv('..\los_angeles_data\la_cleaned_csv\cleaned_la_commute_time.csv', index=False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# <>:2: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\kaitl\AppData\Local\Temp\ipykernel_19196\2243038339.py:2: SyntaxWarning: invalid escape sequence '\l'
#   la_commute_df.to_csv('..\los_angeles_data\la_cleaned_csv\cleaned_la_commute_time.csv', index=False)

# %% [markdown]
# ### Creating JSON File

# %%
# Load the datasets from la 
la_commute_csv = Path('../los_angeles_data/la_cleaned_csv/cleaned_la_commute_time.csv')
la_unemployment_csv = Path('../los_angeles_data/la_cleaned_csv/cleaned_la_unemployment_rate.csv')
la_rent_csv = Path('../los_angeles_data/la_cleaned_csv/cleaned_la_rent.csv')
la_income_csv = Path('../los_angeles_data/la_cleaned_csv/cleaned_la_med_household_income.csv')
la_edu_csv = Path('../los_angeles_data/la_cleaned_csv/cleaned_la_edu_lvl.csv')
la_age_csv = Path('../los_angeles_data/la_cleaned_csv/cleaned_la_age.csv')
la_race_csv = Path('../los_angeles_data/la_cleaned_csv/cleaned_la_race.csv')

# Read the csv files
la_commute_df = pd.read_csv(la_commute_csv)
la_unemployment_df = pd.read_csv(la_unemployment_csv)
la_rent_df = pd.read_csv(la_rent_csv)
la_income_df = pd.read_csv(la_income_csv)
la_edu_df = pd.read_csv(la_edu_csv)
la_age_df = pd.read_csv(la_age_csv)
la_race_df = pd.read_csv(la_race_csv)

# %%
# Combine all data into a dictionary
los_angeles_data = {
    "commute": la_commute_df.to_dict(orient='records'),
    "unemployment": la_unemployment_df.to_dict(orient='records'),
    "rent": la_rent_df.to_dict(orient='records'),
    "income": la_income_df.to_dict(orient='records'),
    "education": la_edu_df.to_dict(orient='records'),
    "age": la_age_df.to_dict(orient='records'),
    "race": la_race_df.to_dict(orient='records')
}

# %%
# Save the dictionary as a JSON file
with open('../los_angeles_data/la_data.json', 'w') as json_file:
    json.dump(los_angeles_data, json_file)
