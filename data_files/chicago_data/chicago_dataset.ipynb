# %% [markdown]
# # Chicago Dataset

# %%
# Import dependencies
import os
import csv
import pandas as pd
import json
from pathlib import Path

# %% [markdown]
# ## Demographic Metric
#
# **Measuring**: ACS Median Age, ACS Racial Demographics, Education Level
#
# Data was pulled from the 2020 Chicago Census Database and the American Community Survey (ACS) by the U.S. Census Bureau using various coded tables to ensure unified data for each metropolitan city. Two tables used the same code and were seperated to ensure proper measurement.
# * ACS Median Age: Table DP05
# * Racial Demograpics: Table DP05
# * Education Level: S1501

# %% [markdown]
# #### ACS Median Age (Table DP05)

# %%
# Import csv file age data (ACS 2020) 
chicago_age_data = '../chicago_data/chi_raw_csv/chi_age_demo.csv'

# Read csv file into DataFrame
chicago_age_df = pd.read_csv(chicago_age_data)
chicago_age_df.head()
# Out:
#         Label (Grouping)  SEX AND AGE SEX AND AGE!!Total population  \
# 0               Illinois          NaN                           NaN
# 1               Estimate          NaN                    12,716,164
# 2                Percent          NaN                    12,716,164
# 3  Cook County, Illinois          NaN                           NaN
# 4               Estimate          NaN                     5,169,517
#
#   SEX AND AGE!!Total population!!Male SEX AND AGE!!Total population!!Female  \
# 0                                 NaN                                   NaN
# 1                           6,247,083                             6,469,081
# 2                               49.1%                                 50.9%
# 3                                 NaN                                   NaN
# 4                           2,509,686                             2,659,831
#
#   SEX AND AGE!!Total population!!Under 5 years  \
# 0                                          NaN
# 1                                      755,518
# 2                                         5.9%
# 3                                          NaN
# 4                                      315,368
#
#   SEX AND AGE!!Total population!!5 to 9 years  \
# 0                                         NaN
# 1                                     768,804
# 2                                        6.0%
# 3                                         NaN
# 4                                     302,232
#
#   SEX AND AGE!!Total population!!10 to 14 years  \
# 0                                           NaN
# 1                                       829,779
# 2                                          6.5%
# 3                                           NaN
# 4                                       322,415
#
#   SEX AND AGE!!Total population!!15 to 19 years  \
# 0                                           NaN
# 1                                       831,088
# 2                                          6.5%
# 3                                           NaN
# 4                                       310,116
#
#   SEX AND AGE!!Total population!!20 to 24 years  ...  \
# 0                                           NaN  ...
# 1                                       844,275  ...
# 2                                          6.6%  ...
# 3                                           NaN  ...
# 4                                       334,453  ...
#
#   SEX AND AGE!!Total population!!75 to 84 years  \
# 0                                           NaN
# 1                                       573,017
# 2                                          4.5%
# 3                                           NaN
# 4                                       219,634
#
#   SEX AND AGE!!Total population!!85 years and over  \
# 0                                              NaN
# 1                                          270,768
# 2                                             2.1%
# 3                                              NaN
# 4                                          104,191
#
#   SEX AND AGE!!Total population!!Median age (years)  \
# 0                                               NaN
# 1                                              38.3
# 2                                               (X)
# 3                                               NaN
# 4                                              37.0
#
#   SEX AND AGE!!Total population!!Under 18 years  \
# 0                                           NaN
# 1                                     2,855,433
# 2                                         22.5%
# 3                                           NaN
# 4                                     1,128,625
#
#   SEX AND AGE!!Total population!!16 years and over  \
# 0                                              NaN
# 1                                       10,193,604
# 2                                            80.2%
# 3                                              NaN
# 4                                        4,167,295
#
#   SEX AND AGE!!Total population!!18 years and over  \
# 0                                              NaN
# 1                                        9,860,731
# 2                                            77.5%
# 3                                              NaN
# 4                                        4,040,892
#
#   SEX AND AGE!!Total population!!21 years and over  \
# 0                                              NaN
# 1                                        9,363,657
# 2                                            73.6%
# 3                                              NaN
# 4                                        3,859,321
#
#   SEX AND AGE!!Total population!!62 years and over  \
# 0                                              NaN
# 1                                        2,443,504
# 2                                            19.2%
# 3                                              NaN
# 4                                          931,306
#
#   SEX AND AGE!!Total population!!65 years and over  \
# 0                                              NaN
# 1                                        1,990,426
# 2                                            15.7%
# 3                                              NaN
# 4                                          757,688
#
#   SEX AND AGE!!Total population!!18 years and over.1
# 0                                                NaN
# 1                                          9,860,731
# 2                                          9,860,731
# 3                                                NaN
# 4                                          4,040,892
#
# [5 rows x 26 columns]

# %%
# Drop all rows where 'Label (Grouping)' column contains 'Illinois'
chicago_age_df = chicago_age_df[chicago_age_df['Label (Grouping)'] != 'Illinois']
chicago_age_df.head()
# Out:
#         Label (Grouping)  SEX AND AGE SEX AND AGE!!Total population  \
# 1               Estimate          NaN                    12,716,164
# 2                Percent          NaN                    12,716,164
# 3  Cook County, Illinois          NaN                           NaN
# 4               Estimate          NaN                     5,169,517
# 5                Percent          NaN                     5,169,517
#
#   SEX AND AGE!!Total population!!Male SEX AND AGE!!Total population!!Female  \
# 1                           6,247,083                             6,469,081
# 2                               49.1%                                 50.9%
# 3                                 NaN                                   NaN
# 4                           2,509,686                             2,659,831
# 5                               48.5%                                 51.5%
#
#   SEX AND AGE!!Total population!!Under 5 years  \
# 1                                      755,518
# 2                                         5.9%
# 3                                          NaN
# 4                                      315,368
# 5                                         6.1%
#
#   SEX AND AGE!!Total population!!5 to 9 years  \
# 1                                     768,804
# 2                                        6.0%
# 3                                         NaN
# 4                                     302,232
# 5                                        5.8%
#
#   SEX AND AGE!!Total population!!10 to 14 years  \
# 1                                       829,779
# 2                                          6.5%
# 3                                           NaN
# 4                                       322,415
# 5                                          6.2%
#
#   SEX AND AGE!!Total population!!15 to 19 years  \
# 1                                       831,088
# 2                                          6.5%
# 3                                           NaN
# 4                                       310,116
# 5                                          6.0%
#
#   SEX AND AGE!!Total population!!20 to 24 years  ...  \
# 1                                       844,275  ...
# 2                                          6.6%  ...
# 3                                           NaN  ...
# 4                                       334,453  ...
# 5                                          6.5%  ...
#
#   SEX AND AGE!!Total population!!75 to 84 years  \
# 1                                       573,017
# 2                                          4.5%
# 3                                           NaN
# 4                                       219,634
# 5                                          4.2%
#
#   SEX AND AGE!!Total population!!85 years and over  \
# 1                                          270,768
# 2                                             2.1%
# 3                                              NaN
# 4                                          104,191
# 5                                             2.0%
#
#   SEX AND AGE!!Total population!!Median age (years)  \
# 1                                              38.3
# 2                                               (X)
# 3                                               NaN
# 4                                              37.0
# 5                                               (X)
#
#   SEX AND AGE!!Total population!!Under 18 years  \
# 1                                     2,855,433
# 2                                         22.5%
# 3                                           NaN
# 4                                     1,128,625
# 5                                         21.8%
#
#   SEX AND AGE!!Total population!!16 years and over  \
# 1                                       10,193,604
# 2                                            80.2%
# 3                                              NaN
# 4                                        4,167,295
# 5                                            80.6%
#
#   SEX AND AGE!!Total population!!18 years and over  \
# 1                                        9,860,731
# 2                                            77.5%
# 3                                              NaN
# 4                                        4,040,892
# 5                                            78.2%
#
#   SEX AND AGE!!Total population!!21 years and over  \
# 1                                        9,363,657
# 2                                            73.6%
# 3                                              NaN
# 4                                        3,859,321
# 5                                            74.7%
#
#   SEX AND AGE!!Total population!!62 years and over  \
# 1                                        2,443,504
# 2                                            19.2%
# 3                                              NaN
# 4                                          931,306
# 5                                            18.0%
#
#   SEX AND AGE!!Total population!!65 years and over  \
# 1                                        1,990,426
# 2                                            15.7%
# 3                                              NaN
# 4                                          757,688
# 5                                            14.7%
#
#   SEX AND AGE!!Total population!!18 years and over.1
# 1                                          9,860,731
# 2                                          9,860,731
# 3                                                NaN
# 4                                          4,040,892
# 5                                          4,040,892
#
# [5 rows x 26 columns]

# %%
# Drop first 2 rows (contain unnecessary Illinois data)
chicago_age_df = chicago_age_df.drop(index=[1, 2])
chicago_age_df.head()
# Out:
#         Label (Grouping)  SEX AND AGE SEX AND AGE!!Total population  \
# 3  Cook County, Illinois          NaN                           NaN
# 4               Estimate          NaN                     5,169,517
# 5                Percent          NaN                     5,169,517
#
#   SEX AND AGE!!Total population!!Male SEX AND AGE!!Total population!!Female  \
# 3                                 NaN                                   NaN
# 4                           2,509,686                             2,659,831
# 5                               48.5%                                 51.5%
#
#   SEX AND AGE!!Total population!!Under 5 years  \
# 3                                          NaN
# 4                                      315,368
# 5                                         6.1%
#
#   SEX AND AGE!!Total population!!5 to 9 years  \
# 3                                         NaN
# 4                                     302,232
# 5                                        5.8%
#
#   SEX AND AGE!!Total population!!10 to 14 years  \
# 3                                           NaN
# 4                                       322,415
# 5                                          6.2%
#
#   SEX AND AGE!!Total population!!15 to 19 years  \
# 3                                           NaN
# 4                                       310,116
# 5                                          6.0%
#
#   SEX AND AGE!!Total population!!20 to 24 years  ...  \
# 3                                           NaN  ...
# 4                                       334,453  ...
# 5                                          6.5%  ...
#
#   SEX AND AGE!!Total population!!75 to 84 years  \
# 3                                           NaN
# 4                                       219,634
# 5                                          4.2%
#
#   SEX AND AGE!!Total population!!85 years and over  \
# 3                                              NaN
# 4                                          104,191
# 5                                             2.0%
#
#   SEX AND AGE!!Total population!!Median age (years)  \
# 3                                               NaN
# 4                                              37.0
# 5                                               (X)
#
#   SEX AND AGE!!Total population!!Under 18 years  \
# 3                                           NaN
# 4                                     1,128,625
# 5                                         21.8%
#
#   SEX AND AGE!!Total population!!16 years and over  \
# 3                                              NaN
# 4                                        4,167,295
# 5                                            80.6%
#
#   SEX AND AGE!!Total population!!18 years and over  \
# 3                                              NaN
# 4                                        4,040,892
# 5                                            78.2%
#
#   SEX AND AGE!!Total population!!21 years and over  \
# 3                                              NaN
# 4                                        3,859,321
# 5                                            74.7%
#
#   SEX AND AGE!!Total population!!62 years and over  \
# 3                                              NaN
# 4                                          931,306
# 5                                            18.0%
#
#   SEX AND AGE!!Total population!!65 years and over  \
# 3                                              NaN
# 4                                          757,688
# 5                                            14.7%
#
#   SEX AND AGE!!Total population!!18 years and over.1
# 3                                                NaN
# 4                                          4,040,892
# 5                                          4,040,892
#
# [3 rows x 26 columns]

# %%
# Display columns and data types
chicago_age_df.dtypes
# Out:
# Label (Grouping)                                       object
# SEX AND AGE                                           float64
# SEX AND AGE!!Total population                          object
# SEX AND AGE!!Total population!!Male                    object
# SEX AND AGE!!Total population!!Female                  object
# SEX AND AGE!!Total population!!Under 5 years           object
# SEX AND AGE!!Total population!!5 to 9 years            object
# SEX AND AGE!!Total population!!10 to 14 years          object
# SEX AND AGE!!Total population!!15 to 19 years          object
# SEX AND AGE!!Total population!!20 to 24 years          object
# SEX AND AGE!!Total population!!25 to 34 years          object
# SEX AND AGE!!Total population!!35 to 44 years          object
# SEX AND AGE!!Total population!!45 to 54 years          object
# SEX AND AGE!!Total population!!55 to 59 years          object
# SEX AND AGE!!Total population!!60 to 64 years          object
# SEX AND AGE!!Total population!!65 to 74 years          object
# SEX AND AGE!!Total population!!75 to 84 years          object
# SEX AND AGE!!Total population!!85 years and over       object
# SEX AND AGE!!Total population!!Median age (years)      object
# SEX AND AGE!!Total population!!Under 18 years          object
# SEX AND AGE!!Total population!!16 years and over       object
# SEX AND AGE!!Total population!!18 years and over       object
# SEX AND AGE!!Total population!!21 years and over       object
# SEX AND AGE!!Total population!!62 years and over       object
# SEX AND AGE!!Total population!!65 years and over       object
# SEX AND AGE!!Total population!!18 years and over.1     object
# dtype: object

# %%
# Rename columns to remove 'SEX AND AGE' from the column names
chicago_age_df.columns = chicago_age_df.columns.str.replace('SEX AND AGE!!', '')

# Drop unnecessary columns
chicago_age_df = chicago_age_df.drop(columns=['Total population!!16 years and over',
                                              'Total population!!18 years and over.1',
                                              'Total population!!62 years and over',
                                              'Total population!!21 years and over',
                                              'Total population!!Under 18 years',
                                              'Total population!!65 years and over',
                                              'Total population!!Male',
                                              'Total population!!Female',
                                              'SEX AND AGE',
                                              'Total population!!18 years and over'
                                            ])

# %%
chicago_age_df.dtypes
# Out:
# Label (Grouping)                        object
# Total population                        object
# Total population!!Under 5 years         object
# Total population!!5 to 9 years          object
# Total population!!10 to 14 years        object
# Total population!!15 to 19 years        object
# Total population!!20 to 24 years        object
# Total population!!25 to 34 years        object
# Total population!!35 to 44 years        object
# Total population!!45 to 54 years        object
# Total population!!55 to 59 years        object
# Total population!!60 to 64 years        object
# Total population!!65 to 74 years        object
# Total population!!75 to 84 years        object
# Total population!!85 years and over     object
# Total population!!Median age (years)    object
# dtype: object

# %%
# Rename columns for clarity
chicago_age_df.columns = ['',
  'Total Population',
  'Under 5',
  '5 to 9',
  '10 to 14',
  '15 to 19',
  '20 to 24',
  '25 to 34',
  '35 to 44',
  '45 to 54',
  '55 to 59',
  '60 to 64',
  '65 to 74',
  '75 to 84',
  '85 and Over',
  'Median Age'
]

chicago_age_df.head()
# Out:
#                 Total Population  Under 5   5 to 9 10 to 14 15 to 19 20 to 24  \
# 4      Estimate        5,169,517  315,368  302,232  322,415  310,116  334,453
# 5       Percent        5,169,517     6.1%     5.8%     6.2%     6.0%     6.5%
#
#   25 to 34 35 to 44 45 to 54 55 to 59 60 to 64 65 to 74 75 to 84 85 and Over  \
# 4  844,827  699,725  647,738  330,348  304,607  433,863  219,634     104,191
# 5    16.3%    13.5%    12.5%     6.4%     5.9%     8.4%     4.2%        2.0%
#
#   Median Age
# 4       37.0
# 5        (X)

# %%
# Drop NaN values from the DataFrame
chicago_age_df = chicago_age_df.dropna()

# %%
# Save the cleaned DataFrame to a new CSV file
chicago_age_df.to_csv('../chicago_data/cleaned_chi_age.csv', index=False)

# %% [markdown]
# #### Racial Demographics (Table DP05)

# %%
# Import csv file for race data
chicago_race_data = '../chicago_data/chi_raw_csv/chi_race.csv'

# Read csv file into DataFrame
chicago_race_df = pd.read_csv(chicago_race_data)
chicago_race_df.head()
# Out:
#         Label (Grouping)  RACE  \
# 0               Illinois   NaN
# 1               Estimate   NaN
# 2                Percent   NaN
# 3  Cook County, Illinois   NaN
# 4               Estimate   NaN
#
#   Race alone or in combination with one or more other races!!Total population  \
# 0                                                NaN
# 1                                         12,716,164
# 2                                         12,716,164
# 3                                                NaN
# 4                                          5,169,517
#
#   Race alone or in combination with one or more other races!!Total population!!White  \
# 0                                                NaN
# 1                                          9,367,474
# 2                                              73.7%
# 3                                                NaN
# 4                                          3,041,776
#
#   Race alone or in combination with one or more other races!!Total population!!Black or African American  \
# 0                                                NaN
# 1                                          1,957,092
# 2                                              15.4%
# 3                                                NaN
# 4                                          1,263,902
#
#   Race alone or in combination with one or more other races!!Total population!!American Indian and Alaska Native  \
# 0                                                NaN
# 1                                            104,386
# 2                                               0.8%
# 3                                                NaN
# 4                                             43,551
#
#   Race alone or in combination with one or more other races!!Total population!!Asian  \
# 0                                                NaN
# 1                                            828,847
# 2                                               6.5%
# 3                                                NaN
# 4                                            445,203
#
#   Race alone or in combination with one or more other races!!Total population!!Native Hawaiian and Other Pacific Islander  \
# 0                                                NaN
# 1                                             16,535
# 2                                               0.1%
# 3                                                NaN
# 4                                              6,818
#
#   Race alone or in combination with one or more other races!!Total population!!Some other race
# 0                                                NaN
# 1                                          1,013,633
# 2                                               8.0%
# 3                                                NaN
# 4                                            640,553

# %%
# Delete the first row (contains unnecessary Illinois data)
chicago_race_df = chicago_race_df[chicago_race_df['Label (Grouping)'] != 'Illinois']

# %%
# Delete first 2 rows
chicago_race_df = chicago_race_df.drop(index=[1, 2])
chicago_race_df.head()
# Out:
#         Label (Grouping)  RACE  \
# 3  Cook County, Illinois   NaN
# 4               Estimate   NaN
# 5                Percent   NaN
#
#   Race alone or in combination with one or more other races!!Total population  \
# 3                                                NaN
# 4                                          5,169,517
# 5                                          5,169,517
#
#   Race alone or in combination with one or more other races!!Total population!!White  \
# 3                                                NaN
# 4                                          3,041,776
# 5                                              58.8%
#
#   Race alone or in combination with one or more other races!!Total population!!Black or African American  \
# 3                                                NaN
# 4                                          1,263,902
# 5                                              24.4%
#
#   Race alone or in combination with one or more other races!!Total population!!American Indian and Alaska Native  \
# 3                                                NaN
# 4                                             43,551
# 5                                               0.8%
#
#   Race alone or in combination with one or more other races!!Total population!!Asian  \
# 3                                                NaN
# 4                                            445,203
# 5                                               8.6%
#
#   Race alone or in combination with one or more other races!!Total population!!Native Hawaiian and Other Pacific Islander  \
# 3                                                NaN
# 4                                              6,818
# 5                                               0.1%
#
#   Race alone or in combination with one or more other races!!Total population!!Some other race
# 3                                                NaN
# 4                                            640,553
# 5                                              12.4%

# %%
# Rename columns to remove 'Race alone or in combination with one or more other races!!Total population!!' from the column names
chicago_race_df.columns = chicago_race_df.columns.str.replace('Race alone or in combination with one or more other races!!Total population!!', '')

# Delete 'Race' column
chicago_race_df = chicago_race_df.drop(columns=['RACE'])

# Display the cleaned DataFrame
chicago_race_df.head()
# Out:
#         Label (Grouping)  \
# 3  Cook County, Illinois
# 4               Estimate
# 5                Percent
#
#   Race alone or in combination with one or more other races!!Total population  \
# 3                                                NaN
# 4                                          5,169,517
# 5                                          5,169,517
#
#        White Black or African American American Indian and Alaska Native  \
# 3        NaN                       NaN                               NaN
# 4  3,041,776                 1,263,902                            43,551
# 5      58.8%                     24.4%                              0.8%
#
#      Asian Native Hawaiian and Other Pacific Islander Some other race
# 3      NaN                                        NaN             NaN
# 4  445,203                                      6,818         640,553
# 5     8.6%                                       0.1%           12.4%

# %%
# Delete NaN values
chicago_race_df = chicago_race_df.dropna()

# %%
# Rename columns for clarity 
chicago_race_df.columns = ['', 
                           'Total Population', 
                           'White', 
                           'Black or African American', 
                           'American Indian and Alaska Native', 
                           'Asian', 
                           'Native Hawaiian and Other Pacific Islander', 
                           'Other']

# Display
chicago_race_df.head()
# Out:
#                 Total Population      White Black or African American  \
# 4      Estimate        5,169,517  3,041,776                 1,263,902
# 5       Percent        5,169,517      58.8%                     24.4%
#
#   American Indian and Alaska Native    Asian  \
# 4                            43,551  445,203
# 5                              0.8%     8.6%
#
#   Native Hawaiian and Other Pacific Islander    Other
# 4                                      6,818  640,553
# 5                                       0.1%    12.4%

# %%
# Save the cleaned DataFrame to a new CSV file
chicago_race_df.to_csv('../chicago_data/cleaned_chi_race.csv', index=False)

# %% [markdown]
# #### Education Level (Table S1501)

# %%
# Import csv file for education data 
chicago_edu_data = '../chicago_data/chi_raw_csv/chicago_edu_level.csv'

# Read the CSV file into a DataFrame
chicago_edu_df = pd.read_csv(chicago_edu_data)
chicago_edu_df.head()
# Out:
#                                     Label (Grouping)  \
# 0                      AGE BY EDUCATIONAL ATTAINMENT
# 1                          Population 18 to 24 years
# 2                     Less than high school graduate
# 3          High school graduate (includes equival...
# 4                 Some college or associate's degree
#
#   Cook County, Illinois!!Total!!Estimate  \
# 0                                    NaN
# 1                                455,959
# 2                                 53,361
# 3                                128,409
# 4                                191,084
#
#   Cook County, Illinois!!Male!!Estimate  \
# 0                                   NaN
# 1                               226,496
# 2                                30,020
# 3                                69,900
# 4                                90,133
#
#   Cook County, Illinois!!Female!!Estimate
# 0                                     NaN
# 1                                 229,463
# 2                                  23,341
# 3                                  58,509
# 4                                 100,951

# %%
# Source data (filter only what is needed out of dataset)
chicago_edu_df = chicago_edu_df.iloc[:28]
chicago_edu_df.head()
# Out:
#                                     Label (Grouping)  \
# 0                      AGE BY EDUCATIONAL ATTAINMENT
# 1                          Population 18 to 24 years
# 2                     Less than high school graduate
# 3          High school graduate (includes equival...
# 4                 Some college or associate's degree
#
#   Cook County, Illinois!!Total!!Estimate  \
# 0                                    NaN
# 1                                455,959
# 2                                 53,361
# 3                                128,409
# 4                                191,084
#
#   Cook County, Illinois!!Male!!Estimate  \
# 0                                   NaN
# 1                               226,496
# 2                                30,020
# 3                                69,900
# 4                                90,133
#
#   Cook County, Illinois!!Female!!Estimate
# 0                                     NaN
# 1                                 229,463
# 2                                  23,341
# 3                                  58,509
# 4                                 100,951

# %%
# Drop NaN values
chicago_edu_df = chicago_edu_df.dropna()

# %%
# Rename columns for clarity
chicago_edu_df.columns = ['Age by Educational Attainment',
                          'Total', 
                            'Male',
                            'Female']

# Display the cleaned DataFrame
chicago_edu_df.head()
# Out:
#                        Age by Educational Attainment    Total     Male  \
# 1                          Population 18 to 24 years  455,959  226,496
# 2                     Less than high school graduate   53,361   30,020
# 3          High school graduate (includes equival...  128,409   69,900
# 4                 Some college or associate's degree  191,084   90,133
# 5                        Bachelor's degree or higher   83,105   36,443
#
#     Female
# 1  229,463
# 2   23,341
# 3   58,509
# 4  100,951
# 5   46,662

# %%
# save the cleaned DataFrame to a new CSV file
chicago_edu_df.to_csv('../chicago_data/chi_cleaned_csv/cleaned_chi_edu.csv', index=False)

# %% [markdown]
# ## Economic Metric
#
# **Measuring**: Median Household Income, Unemployment Rate.
#
# Data for this section was pulled from the Chicago 2020 Census Database using various coded tables:
# * Median Household Income: Table S1901
# * Unemployment Rate: Table S2301

# %% [markdown]
# ##### Median Household Income (Table S1901)

# %%
# Import new csv file for Median Household Income
chicago_income_data = '../chicago_data/chi_raw_csv/chicago_income.csv'

# Read the csv file
chicago_income_df = pd.read_csv(chicago_income_data)
chicago_income_df.head()
# Out:
#          Label (Grouping) Cook County, Illinois!!Households!!Estimate  \
# 0                   Total                                   1,991,474
# 1       Less than $10,000                                        7.1%
# 2      $10,000 to $14,999                                        3.8%
# 3      $15,000 to $24,999                                        8.3%
# 4      $25,000 to $34,999                                        8.1%
#
#   Cook County, Illinois!!Families!!Estimate  \
# 0                                 1,183,425
# 1                                      4.0%
# 2                                      2.2%
# 3                                      6.1%
# 4                                      7.1%
#
#   Cook County, Illinois!!Married-couple families!!Estimate  \
# 0                                            807,194
# 1                                               1.4%
# 2                                               1.1%
# 3                                               3.5%
# 4                                               5.0%
#
#   Cook County, Illinois!!Nonfamily households!!Estimate
# 0                                            808,049
# 1                                              12.2%
# 2                                               6.5%
# 3                                              12.0%
# 4                                               9.9%

# %%
# Droping unnecessary rows and columns
chicago_income_df = chicago_income_df.iloc[:13]

# %%
# Rewrite for clarity
chicago_income_df.columns = ['',
                             'Household', 
                              'Families', 
                              'Married-couple Households', 
                              'Nonfamily Households']
chicago_income_df.head()
# Out:
#                            Household   Families Married-couple Households  \
# 0                   Total  1,991,474  1,183,425                   807,194
# 1       Less than $10,000       7.1%       4.0%                      1.4%
# 2      $10,000 to $14,999       3.8%       2.2%                      1.1%
# 3      $15,000 to $24,999       8.3%       6.1%                      3.5%
# 4      $25,000 to $34,999       8.1%       7.1%                      5.0%
#
#   Nonfamily Households
# 0              808,049
# 1                12.2%
# 2                 6.5%
# 3                12.0%
# 4                 9.9%

# %%
# Save the cleaned DataFrame to a new CSV file
chicago_income_df.to_csv('../chicago_data/cleaned_chi_income.csv', index=False)

# %% [markdown]
# ##### Unemployment Rate (Table S2301)

# %%
# Import new csv file for Unemployment Rate
chicago_employment_data = '../chicago_data/chi_raw_csv/chicago_employment_status.csv'

# Read the csv file
chicago_employment_df = pd.read_csv(chicago_employment_data)
chicago_employment_df.head()
# Out:
#                Label (Grouping) Cook County, Illinois!!Total!!Estimate  \
# 0  Population 16 years and over                              4,167,295
# 1                           AGE                                    NaN
# 2                16 to 19 years                                247,909
# 3                20 to 24 years                                334,453
# 4                25 to 29 years                                432,731
#
#   Cook County, Illinois!!Labor Force Participation Rate!!Estimate  \
# 0                                              66.1%
# 1                                                NaN
# 2                                              31.9%
# 3                                              74.0%
# 4                                              85.7%
#
#   Cook County, Illinois!!Employment/Population Ratio!!Estimate  \
# 0                                              61.5%
# 1                                                NaN
# 2                                              24.0%
# 3                                              63.5%
# 4                                              79.3%
#
#   Cook County, Illinois!!Unemployment rate!!Estimate
# 0                                               7.0%
# 1                                                NaN
# 2                                              24.6%
# 3                                              14.0%
# 4                                               7.5%

# %%
# Filter the DataFrame to only include rows 0-11
chicago_employment_df = chicago_employment_df.iloc[0:12]

# Display the filtered DataFrame
chicago_employment_df.head()
# Out:
#                Label (Grouping) Cook County, Illinois!!Total!!Estimate  \
# 0  Population 16 years and over                              4,167,295
# 1                           AGE                                    NaN
# 2                16 to 19 years                                247,909
# 3                20 to 24 years                                334,453
# 4                25 to 29 years                                432,731
#
#   Cook County, Illinois!!Labor Force Participation Rate!!Estimate  \
# 0                                              66.1%
# 1                                                NaN
# 2                                              31.9%
# 3                                              74.0%
# 4                                              85.7%
#
#   Cook County, Illinois!!Employment/Population Ratio!!Estimate  \
# 0                                              61.5%
# 1                                                NaN
# 2                                              24.0%
# 3                                              63.5%
# 4                                              79.3%
#
#   Cook County, Illinois!!Unemployment rate!!Estimate
# 0                                               7.0%
# 1                                                NaN
# 2                                              24.6%
# 3                                              14.0%
# 4                                               7.5%

# %%
# Drop any NaN values
chicago_employment_df = chicago_employment_df.dropna()

# %%
# Rename columns for clarity
chicago_employment_df.columns = ['Age Group', 
                                   'Total', 
                                   'Labor Force Participation', 
                                   'Employment Population Ratio', 
                                   'Unemployment Rate']
chicago_employment_df.head()
# Out:
#                       Age Group      Total Labor Force Participation  \
# 0  Population 16 years and over  4,167,295                     66.1%
# 2                16 to 19 years    247,909                     31.9%
# 3                20 to 24 years    334,453                     74.0%
# 4                25 to 29 years    432,731                     85.7%
# 5                30 to 34 years    412,096                     86.6%
#
#   Employment Population Ratio Unemployment Rate
# 0                       61.5%              7.0%
# 2                       24.0%             24.6%
# 3                       63.5%             14.0%
# 4                       79.3%              7.5%
# 5                       81.4%              5.8%

# %%
# Save the cleaned DataFrame to a new CSV file
chicago_income_df.to_csv('../chicago_data/cleaned_chi_employment.csv', index=False)

# %% [markdown]
# ## Housing  Metric
#
# **Measuring**: Median Rent
#
# Data for this section was pulled from the Chicago 2020 Census Database using the same table code from the American Community Survey by the U.S. Census Bureau (ACS).
# * Median Rent: Table DP04

# %%
# Import new csv file
chicago_rent_data = '../chicago_data/chi_raw_csv/chicago_gross_rent.csv'

# Read the csv file
chicago_rent_df = pd.read_csv(chicago_rent_data)
chicago_rent_df.head()
# Out:
#         Label (Grouping) HOUSING OCCUPANCY!!Total housing units  \
# 0  Cook County, Illinois                                    NaN
# 1               Estimate                              2,198,489
# 2                Percent                              2,198,489
#
#   GROSS RENT!!Occupied units paying rent  \
# 0                                    NaN
# 1                                826,287
# 2                                826,287
#
#   GROSS RENT!!Occupied units paying rent!!Less than $500  \
# 0                                                NaN
# 1                                             63,894
# 2                                               7.7%
#
#   GROSS RENT!!Occupied units paying rent!!$500 to $999  \
# 0                                                NaN
# 1                                            239,710
# 2                                              29.0%
#
#   GROSS RENT!!Occupied units paying rent!!$1,000 to $1,499  \
# 0                                                NaN
# 1                                            284,235
# 2                                              34.4%
#
#   GROSS RENT!!Occupied units paying rent!!$1,500 to $1,999  \
# 0                                                NaN
# 1                                            136,924
# 2                                              16.6%
#
#   GROSS RENT!!Occupied units paying rent!!$2,000 to $2,499  \
# 0                                                NaN
# 1                                             59,665
# 2                                               7.2%
#
#   GROSS RENT!!Occupied units paying rent!!$2,500 to $2,999  \
# 0                                                NaN
# 1                                             23,888
# 2                                               2.9%
#
#   GROSS RENT!!Occupied units paying rent!!$3,000 or more  \
# 0                                                NaN
# 1                                             17,971
# 2                                               2.2%
#
#   GROSS RENT!!Occupied units paying rent!!Median (dollars)  \
# 0                                                NaN
# 1                                              1,160
# 2                                                (X)
#
#   GROSS RENT!!Occupied units paying rent!!No rent paid
# 0                                                NaN
# 1                                             25,249
# 2                                                (X)

# %%
# Drop NaN values
chicago_rent_df = chicago_rent_df.dropna()

# %%
# Rename columns for clarity
chicago_rent_df.columns = ['',
                             'Total Housing Units',
                             'Occupied Housing Units Paying Rent',
                             'Less than $500',
                             '$500 to $999',
                             '$1,000 to $1,499',
                             '$1,500 to $1,999',
                             '$2,000 to $2,499',
                             '$2,500 to $2,999',
                             '$3,000 or more',
                             'Median Rent Price',
                             'No rent paid'
]
chicago_rent_df
# Out:
#                 Total Housing Units Occupied Housing Units Paying Rent  \
# 1      Estimate           2,198,489                            826,287
# 2       Percent           2,198,489                            826,287
#
#   Less than $500 $500 to $999 $1,000 to $1,499 $1,500 to $1,999  \
# 1         63,894      239,710          284,235          136,924
# 2           7.7%        29.0%            34.4%            16.6%
#
#   $2,000 to $2,499 $2,500 to $2,999 $3,000 or more Median Rent Price  \
# 1           59,665           23,888         17,971             1,160
# 2             7.2%             2.9%           2.2%               (X)
#
#   No rent paid
# 1       25,249
# 2          (X)

# %%
# Save the cleaned DataFrame to a new CSV file
chicago_income_df.to_csv('../chicago_data/cleaned_chi_rent.csv', index=False)

# %% [markdown]
# ## Quality of Life Metric
#
# **Measuring**: Commute Time
#
# Data was pulled from the Census Database using the following survey by ASC in 2020.
# * Commute Time: Table S0801
# * Health Outcomes

# %%
# Import new csv file for Commute Time
chicago_commute_data = '../chicago_data/chi_raw_csv/chicago_commute.csv'

# Read the csv file
chicago_commute_df = pd.read_csv(chicago_commute_data)
chicago_commute_df.head()
# Out:
#                       Label (Grouping) Cook County, Illinois!!Total!!Estimate  \
# 0            Workers 16 years and over                              2,508,211
# 1      MEANS OF TRANSPORTATION TO WORK                                    NaN
# 2                   Car, truck, or van                                  67.7%
# 3                          Drove alone                                  59.9%
# 4                            Carpooled                                   7.8%
#
#   Cook County, Illinois!!Male!!Estimate  \
# 0                             1,305,661
# 1                                   NaN
# 2                                 68.9%
# 3                                 61.3%
# 4                                  7.6%
#
#   Cook County, Illinois!!Female!!Estimate
# 0                               1,202,550
# 1                                     NaN
# 2                                   66.4%
# 3                                   58.4%
# 4                                    8.0%

# %%
chicago_commute_df = chicago_commute_df.iloc[:14]
chicago_commute_df.head()
# Out:
#                       Label (Grouping) Cook County, Illinois!!Total!!Estimate  \
# 0            Workers 16 years and over                              2,508,211
# 1      MEANS OF TRANSPORTATION TO WORK                                    NaN
# 2                   Car, truck, or van                                  67.7%
# 3                          Drove alone                                  59.9%
# 4                            Carpooled                                   7.8%
#
#   Cook County, Illinois!!Male!!Estimate  \
# 0                             1,305,661
# 1                                   NaN
# 2                                 68.9%
# 3                                 61.3%
# 4                                  7.6%
#
#   Cook County, Illinois!!Female!!Estimate
# 0                               1,202,550
# 1                                     NaN
# 2                                   66.4%
# 3                                   58.4%
# 4                                    8.0%

# %%
# Delete NaN values
chicago_commute_df = chicago_commute_df.dropna()

# %%
# Rewrite for clarity 
chicago_commute_df.columns = ['',
                              'Total Estimate',
                              'Male',
                              'Female'
                              ]
chicago_commute_df.head()
# Out:
#                                        Total Estimate       Male     Female
# 0            Workers 16 years and over      2,508,211  1,305,661  1,202,550
# 2                   Car, truck, or van          67.7%      68.9%      66.4%
# 3                          Drove alone          59.9%      61.3%      58.4%
# 4                            Carpooled           7.8%       7.6%       8.0%
# 5                  In 2-person carpool           5.9%       5.7%       6.1%

# %%
# Save the cleaned DataFrame to a new CSV file
chicago_commute_df.to_csv('../chicago_data/cleaned_chi_commute.csv', index=False)

# %% [markdown]
# #### Health Behaviors & Outcomes

# %%
# Import file (chicago_health_behavior.csv)
chicago_health_data = '../chicago_data/chi_raw_csv/chicago_health_behaviors.csv'

# Read file 
chicago_health_df = pd.read_csv(chicago_health_data)
chicago_health_df.head()
# Out:
#      Entity DCID  Entity properties isoCode Entity properties name  \
# 0  geoId/1714000                        NaN                Chicago
# 1  geoId/1714000                        NaN                Chicago
# 2  geoId/1714000                        NaN                Chicago
# 3  geoId/1714000                        NaN                Chicago
# 4  geoId/1714000                        NaN                Chicago
#
#                         Variable DCID  Variable observation date  \
# 0  Percent_Person_SleepLessThan7Hours                       2020
# 1  Percent_Person_SleepLessThan7Hours                       2022
# 2              Percent_Person_Obesity                       2020
# 3              Percent_Person_Obesity                       2021
# 4              Percent_Person_Obesity                       2022
#
#   Variable observation metadata importName  \
# 0                                   CDC500
# 1                                   CDC500
# 2                                   CDC500
# 3                                   CDC500
# 4                                   CDC500
#
#   Variable observation metadata provenanceUrl  \
# 0       https://www.cdc.gov/places/index.html
# 1       https://www.cdc.gov/places/index.html
# 2       https://www.cdc.gov/places/index.html
# 3       https://www.cdc.gov/places/index.html
# 4       https://www.cdc.gov/places/index.html
#
#    Variable observation metadata scalingFactor  \
# 0                                          100
# 1                                          100
# 2                                          100
# 3                                          100
# 4                                          100
#
#   Variable observation metadata unit  \
# 0                            Percent
# 1                            Percent
# 2                            Percent
# 3                            Percent
# 4                            Percent
#
#   Variable observation metadata unitDisplayName  Variable observation value  \
# 0                                             %                        35.2
# 1                                             %                        37.9
# 2                                             %                        32.2
# 3                                             %                        34.1
# 4                                             %                        35.2
#
#                             Variable properties name
# 0  Percentage of Adult Population That Sleeps Les...
# 1  Percentage of Adult Population That Sleeps Les...
# 2       Percentage of Adult Population That Is Obese
# 3       Percentage of Adult Population That Is Obese
# 4       Percentage of Adult Population That Is Obese

# %%
# Delete unnecessary columns 
chicago_health_df = chicago_health_df.drop(columns=['Entity DCID', 'Entity properties isoCode','Variable observation metadata importName', 'Variable DCID', 'Variable observation metadata importName','Variable observation metadata provenanceUrl','Variable observation metadata scalingFactor', 'Variable observation metadata unit', 'Variable observation metadata unitDisplayName'])
chicago_health_df.head()
# Out:
#   Entity properties name  Variable observation date  \
# 0                Chicago                       2020
# 1                Chicago                       2022
# 2                Chicago                       2020
# 3                Chicago                       2021
# 4                Chicago                       2022
#
#    Variable observation value  \
# 0                        35.2
# 1                        37.9
# 2                        32.2
# 3                        34.1
# 4                        35.2
#
#                             Variable properties name
# 0  Percentage of Adult Population That Sleeps Les...
# 1  Percentage of Adult Population That Sleeps Les...
# 2       Percentage of Adult Population That Is Obese
# 3       Percentage of Adult Population That Is Obese
# 4       Percentage of Adult Population That Is Obese

# %%
# Filter the DataFrame to only include rows where 'Variable observation date' is 2020
chicago_health_df = chicago_health_df[chicago_health_df['Variable observation date'] == 2020]

# Display the filtered DataFrame
chicago_health_df.head()
# Out:
#    Entity properties name  Variable observation date  \
# 0                 Chicago                       2020
# 2                 Chicago                       2020
# 5                 Chicago                       2020
# 8                 Chicago                       2020
# 11                Chicago                       2020
#
#     Variable observation value  \
# 0                         35.2
# 2                         32.2
# 5                         13.4
# 8                         28.6
# 11                        15.0
#
#                              Variable properties name
# 0   Percentage of Adult Population That Sleeps Les...
# 2        Percentage of Adult Population That Is Obese
# 5      Percentage of Adult Population Who Binge Drink
# 8   Percentage of Adult Population Who Are Physica...
# 11         Percentage of Adult Population That Smokes

# %%
# Save the cleaned DataFrame to a new CSV file
chicago_health_df.to_csv('../chicago_data/cleaned_chi_health.csv', index=False)

# %% [markdown]
# ### Creating JSON file

# %%
# Load the datasets from Chicago
chicago_commute_df = pd.read_csv('../chicago_data/chi_cleaned_csv/cleaned_chi_commute.csv')
chicago_unemployment_df = pd.read_csv('../chicago_data/chi_cleaned_csv/cleaned_chi_employment.csv')
chicago_rent_df = pd.read_csv('../chicago_data/chi_cleaned_csv/cleaned_chi_rent.csv')
chicago_income_df = pd.read_csv('../chicago_data/chi_cleaned_csv/cleaned_chi_income.csv')
chicago_edu_df = pd.read_csv('../chicago_data/chi_cleaned_csv/cleaned_chi_edu.csv')
chicago_age_df = pd.read_csv('../chicago_data/chi_cleaned_csv/cleaned_chi_age.csv')
chicago_race_df = pd.read_csv('../chicago_data/chi_cleaned_csv/cleaned_chi_race.csv')
chicago_health_df = pd.read_csv('../chicago_data/chi_cleaned_csv/cleaned_chi_health.csv')

# %%
# Combine all data into a dictionary
chicago_data = {
    "commute": chicago_commute_df.to_dict(orient='records'),
    "unemployment": chicago_unemployment_df.to_dict(orient='records'),
    "rent": chicago_rent_df.to_dict(orient='records'),
    "income": chicago_income_df.to_dict(orient='records'),
    "education": chicago_edu_df.to_dict(orient='records'),
    "age": chicago_age_df.to_dict(orient='records'),
    "race": chicago_race_df.to_dict(orient='records'),
    "health": chicago_health_df.to_dict(orient='records')
}

# %%
# Save the dictionary as a JSON file
with open('../chicago_data/chicago_data.json', 'w') as json_file:
    json.dump(chicago_data, json_file)

# %% [markdown]
# Sources:
# * [chicago_age_demo.csv]()
# * [chicago_housing.csv]()
# * [chicago_race.csv]()
# * [chicago_commute.csv]()
# * [chicago_edu_level.csv]()
# * [chicago_gross_rent.csv]()
# * [chicago_income.csv]()
# * [chicago_health_behaviors.csv](https://datacommons.org/place/geoId/1714000?category=Health)
