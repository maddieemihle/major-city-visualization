# %% [markdown]
# # Chicago Dataset

# %%
# Import dependencies
import os
import csv
import pandas as pd
import openpyxl

# %% [markdown]
# ## Demographic Metric
#
# **Measuring**: ACS Population Density, Median Age, Education Level
#
# Data was pulled from the 2020 Chicago Census Database and the American Community Survey (ACS) by the U.S. Census Bureau using various coded tables to ensure unified data for each metropolitan city. Two tables used the same code and were seperated to ensure proper measurement.
# * ACS Population Density: Table DP05
# * Median Age: Table DP05
# * Education Level: S1501

# %% [markdown]
# #### ACS Population Density & Median Age (Table DP05)

# %%
# Import csv file Chicago ACS Population Density 
chicago_poulation_data = '../chicago_data/chi_ACS_pop_density.csv'

# Read csv file into DataFrame
chicago_population_df = pd.read_csv(chicago_poulation_data)
chicago_population_df.head()
# Out:
#                             Label (Grouping) Illinois!!Estimate  \
# 0                                SEX AND AGE                NaN
# 1                           Total population         12,716,164
# 2                                       Male          6,247,083
# 3                                     Female          6,469,081
# 4          Sex ratio (males per 100 females)               96.6
#
#   Illinois!!Margin of Error Illinois!!Percent  \
# 0                       NaN               NaN
# 1                     *****        12,716,164
# 2                    ±1,174             49.1%
# 3                    ±1,174             50.9%
# 4                      ±0.1               (X)
#
#   Illinois!!Percent Margin of Error  \
# 0                               NaN
# 1                               (X)
# 2                              ±0.1
# 3                              ±0.1
# 4                               (X)
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Estimate  \
# 0                                                NaN
# 1                                          9,478,801
# 2                                          4,640,471
# 3                                          4,838,330
# 4                                               95.9
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Margin of Error  \
# 0                                                NaN
# 1                                              *****
# 2                                               ±544
# 3                                               ±544
# 4                                               ±0.1
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent  \
# 0                                                NaN
# 1                                          9,478,801
# 2                                              49.0%
# 3                                              51.0%
# 4                                                (X)
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Margin of Error
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.1
# 3                                               ±0.1
# 4                                                (X)

# %%
# Display columns and data types
chicago_population_df.dtypes
# Out:
# Label (Grouping)                                                          object
# Illinois!!Estimate                                                        object
# Illinois!!Margin of Error                                                 object
# Illinois!!Percent                                                         object
# Illinois!!Percent Margin of Error                                         object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Estimate                   object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Margin of Error            object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent                    object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Margin of Error    object
# dtype: object

# %%
# Drop unnecessary columns (i.e anything with "Margin of Error")
chicago_population_df = chicago_population_df.drop(columns=['Illinois!!Margin of Error', 
                                                            'Illinois!!Percent Margin of Error', 
                                                            'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Margin of Error',
                                                            'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Margin of Error'])

# %%
# Rename columns for clarity
chicago_population_df = chicago_population_df.rename(columns={
    'Illinois!!Estimate': 'Illinois Total Population',
    'Illinois!!Percent': 'Illinois %',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Estimate': 'Chicago Metro Total Population',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent': 'Chicago Metro %'
})

chicago_population_df.head()
# Out:
#                             Label (Grouping) Illinois Total Population  \
# 0                                SEX AND AGE                       NaN
# 1                           Total population                12,716,164
# 2                                       Male                 6,247,083
# 3                                     Female                 6,469,081
# 4          Sex ratio (males per 100 females)                      96.6
#
#    Illinois % Chicago Metro Total Population Chicago Metro %
# 0         NaN                            NaN             NaN
# 1  12,716,164                      9,478,801       9,478,801
# 2       49.1%                      4,640,471           49.0%
# 3       50.9%                      4,838,330           51.0%
# 4         (X)                           95.9             (X)

# %%
# Save the cleaned DataFrame to a new CSV file
output_csv_path = '../chicago_data/cleaned_chicago_population_density.csv'

# %% [markdown]
# #### Education Level (Table S1501)

# %%
# Import csv file for education data 
chicago_edu_data = '../chicago_data/chi_edu_level.csv'

# Read the CSV file into a DataFrame
chicago_edu_df = pd.read_csv(chicago_edu_data)
chicago_edu_df.head()
# Out:
#                                     Label (Grouping)  \
# 0                      AGE BY EDUCATIONAL ATTAINMENT
# 1                          Population 18 to 24 years
# 2                     Less than high school graduate
# 3          High school graduate (includes equival...
# 4                 Some college or associate's degree
#
#   Illinois!!Total!!Estimate Illinois!!Total!!Margin of Error  \
# 0                       NaN                              NaN
# 1                 1,174,031                             ±964
# 2                   138,521                           ±2,960
# 3                   352,546                           ±3,753
# 4                   513,656                           ±4,458
#
#   Illinois!!Percent!!Estimate Illinois!!Percent!!Margin of Error  \
# 0                         NaN                                NaN
# 1                         (X)                                (X)
# 2                       11.8%                               ±0.3
# 3                       30.0%                               ±0.3
# 4                       43.8%                               ±0.4
#
#   Illinois!!Male!!Estimate Illinois!!Male!!Margin of Error  \
# 0                      NaN                             NaN
# 1                  597,348                            ±710
# 2                   78,436                          ±2,146
# 3                  197,183                          ±3,209
# 4                  248,837                          ±3,286
#
#   Illinois!!Percent Male!!Estimate Illinois!!Percent Male!!Margin of Error  \
# 0                              NaN                                     NaN
# 1                              (X)                                     (X)
# 2                            13.1%                                    ±0.4
# 3                            33.0%                                    ±0.5
# 4                            41.7%                                    ±0.5
#
#   Illinois!!Female!!Estimate  ...  \
# 0                        NaN  ...
# 1                    576,683  ...
# 2                     60,085  ...
# 3                    155,363  ...
# 4                    264,819  ...
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent!!Estimate  \
# 0                                                NaN
# 1                                                (X)
# 2                                              11.8%
# 3                                              30.7%
# 4                                              41.6%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent!!Margin of Error  \
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.3
# 3                                               ±0.4
# 4                                               ±0.5
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Estimate  \
# 0                                                NaN
# 1                                            433,876
# 2                                             56,432
# 3                                            144,304
# 4                                            173,489
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Margin of Error  \
# 0                                                NaN
# 1                                               ±276
# 2                                             ±1,730
# 3                                             ±2,915
# 4                                             ±2,826
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Male!!Estimate  \
# 0                                                NaN
# 1                                                (X)
# 2                                              13.0%
# 3                                              33.3%
# 4                                              40.0%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Male!!Margin of Error  \
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.4
# 3                                               ±0.7
# 4                                               ±0.6
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Estimate  \
# 0                                                NaN
# 1                                            422,068
# 2                                             44,349
# 3                                            118,237
# 4                                            182,196
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Margin of Error  \
# 0                                                NaN
# 1                                               ±448
# 2                                             ±2,071
# 3                                             ±2,477
# 4                                             ±2,849
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Female!!Estimate  \
# 0                                                NaN
# 1                                                (X)
# 2                                              10.5%
# 3                                              28.0%
# 4                                              43.2%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Female!!Margin of Error
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.5
# 3                                               ±0.6
# 4                                               ±0.7
#
# [5 rows x 25 columns]

# %%
# Display columns and data types
chicago_edu_df.dtypes
# Out:
# Label (Grouping)                                                                  object
# Illinois!!Total!!Estimate                                                         object
# Illinois!!Total!!Margin of Error                                                  object
# Illinois!!Percent!!Estimate                                                       object
# Illinois!!Percent!!Margin of Error                                                object
# Illinois!!Male!!Estimate                                                          object
# Illinois!!Male!!Margin of Error                                                   object
# Illinois!!Percent Male!!Estimate                                                  object
# Illinois!!Percent Male!!Margin of Error                                           object
# Illinois!!Female!!Estimate                                                        object
# Illinois!!Female!!Margin of Error                                                 object
# Illinois!!Percent Female!!Estimate                                                object
# Illinois!!Percent Female!!Margin of Error                                         object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate                    object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error             object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent!!Estimate                  object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent!!Margin of Error           object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Estimate                     object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Margin of Error              object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Male!!Estimate             object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Male!!Margin of Error      object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Estimate                   object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Margin of Error            object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Female!!Estimate           object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Female!!Margin of Error    object
# dtype: object

# %%
# Drop unnecessary columns (i.e anything with "Margin of Error")
chicago_edu_df = chicago_edu_df.drop(columns=['Illinois!!Total!!Margin of Error',
                                              'Illinois!!Percent!!Margin of Error',
                                              'Illinois!!Male!!Margin of Error',
                                              'Illinois!!Percent Male!!Margin of Error',
                                              'Illinois!!Female!!Margin of Error',
                                              'Illinois!!Percent Female!!Margin of Error',
                                              'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error',
                                              'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent!!Margin of Error',
                                              'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Margin of Error',
                                              'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Male!!Margin of Error',
                                              'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Margin of Error',
                                              'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Female!!Margin of Error'
                                                ])

# %%
# Drop NaN values
chicago_edu_df = chicago_edu_df.dropna()

# %%
# Rename columns for clarity
chicago_edu_df = chicago_edu_df.rename(columns={
    'Label (Grouping)': 'Age by Educational Attainment',
    'Illinois!!Total!!Estimate': 'Illinois Total Population',
    'Illinois!!Percent!!Estimate': 'Illinois Pop %',
    'Illinois!!Male!!Estimate': 'Illinois Male Population',
    'Illinois!!Percent Male!!Estimate': 'Illinois Male %',
    'Illinois!!Female!!Estimate': 'Illinois Female Population',
    'Illinois!!Percent Female!!Estimate': 'Illinois Female %',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate': 'Chicago Metro Total Population',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent!!Estimate': 'Chicago Metro %',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Estimate': 'Chicago Male Population',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Male!!Estimate': 'Chicago Male %',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Estimate': 'Chicago Female Population',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Female!!Estimate': 'Chicago Female %'
})

# Display the cleaned DataFrame
chicago_edu_df.head()
# Out:
#                        Age by Educational Attainment  \
# 1                          Population 18 to 24 years
# 2                     Less than high school graduate
# 3          High school graduate (includes equival...
# 4                 Some college or associate's degree
# 5                        Bachelor's degree or higher
#
#   Illinois Total Population Illinois % Illinois Male Population  \
# 1                 1,174,031        (X)                  597,348
# 2                   138,521      11.8%                   78,436
# 3                   352,546      30.0%                  197,183
# 4                   513,656      43.8%                  248,837
# 5                   169,308      14.4%                   72,892
#
#   Illinois Male % Illinois Female Population Illinois Female %  \
# 1             (X)                    576,683               (X)
# 2           13.1%                     60,085             10.4%
# 3           33.0%                    155,363             26.9%
# 4           41.7%                    264,819             45.9%
# 5           12.2%                     96,416             16.7%
#
#   Chicago Metro Total Population Chicago Metro % Chicago Male Population  \
# 1                        855,944             (X)                 433,876
# 2                        100,781           11.8%                  56,432
# 3                        262,541           30.7%                 144,304
# 4                        355,685           41.6%                 173,489
# 5                        136,937           16.0%                  59,651
#
#   Chicago Male % Chicago Female Population Chicago Female %
# 1            (X)                   422,068              (X)
# 2          13.0%                    44,349            10.5%
# 3          33.3%                   118,237            28.0%
# 4          40.0%                   182,196            43.2%
# 5          13.7%                    77,286            18.3%

# %%
# save the cleaned DataFrame to a new CSV file

# %% [markdown]
# #### Found: Population Count by Age and Zipcode

# %%
# Import new csv file
chicago_pop_counts = 'data_files/chicago_data/Chicago_Population_Counts.csv'

# Read the csv file
chicago_pop_counts_df = pd.read_csv(chicago_pop_counts)
chicago_pop_counts_df.head()
# Out:
#   Geography Type  Year Geography  Population - Total  Population - Age 0-17  \
# 0       Citywide  2018   Chicago             2705988                 548999
# 1       ZIP Code  2018     60601               14675                    820
# 2       ZIP Code  2018     60602                1244                    149
# 3       ZIP Code  2018     60603                1174                     56
# 4       ZIP Code  2018     60604                 782                     38
#
#    Population - Age 18-29  Population - Age 30-39  Population - Age 40-49  \
# 0                  552935                  456321                  336457
# 1                    4606                    2792                    2190
# 2                     435                     462                     135
# 3                     561                     101                      97
# 4                     303                     104                      51
#
#    Population - Age 50-59  Population - Age 60-69  ...  Population - Age 18+  \
# 0                  312965                  262991  ...               2156989
# 1                    1333                    1340  ...                 13855
# 2                      53                      10  ...                  1095
# 3                     197                      97  ...                  1118
# 4                     101                     130  ...                   744
#
#    Population - Age 65+  Population - Female  Population - Male  \
# 0                349712              1386113            1319875
# 1                  2075                 7484               7191
# 2                     5                  551                693
# 3                   112                  601                573
# 4                    93                  413                369
#
#    Population - Latinx  Population - Asian Non-Latinx  \
# 0               776661                       179841.0
# 1                 1274                            NaN
# 2                   81                            NaN
# 3                  115                            NaN
# 4                   34                            NaN
#
#    Population - Black Non-Latinx  Population - White Non-Latinx  \
# 0                       784266.0                         899980
# 1                            NaN                           9677
# 2                            NaN                            788
# 3                            NaN                            707
# 4                            NaN                            479
#
#    Population - Other Race Non-Latinx              Record ID
# 0                            119467.0  Citywide-Chicago-2018
# 1                                 NaN    ZIP_Code-60601-2018
# 2                                 NaN    ZIP_Code-60602-2018
# 3                                 NaN    ZIP_Code-60603-2018
# 4                                 NaN    ZIP_Code-60604-2018
#
# [5 rows x 26 columns]

# %%
# Clean data by droping any rows that do not have 2020 in the 'Year' column
chicago_pop_counts_2020_df = chicago_pop_counts_df[chicago_pop_counts_df['Year'] == 2020]
chicago_pop_counts_2020_df.head()
# Out:
#     Geography Type  Year Geography  Population - Total  Population - Age 0-17  \
# 120       Citywide  2020   Chicago             2699347                 552668
# 121       ZIP Code  2020     60601               14513                    825
# 122       ZIP Code  2020     60602                1596                    115
# 123       ZIP Code  2020     60603                1186                     15
# 124       ZIP Code  2020     60604                 729                      5
#
#      Population - Age 18-29  Population - Age 30-39  Population - Age 40-49  \
# 120                  548747                  463143                  336591
# 121                    4696                    3048                    1815
# 122                     332                     860                     191
# 123                     423                     248                      68
# 124                     313                     171                      30
#
#      Population - Age 50-59  Population - Age 60-69  ...  \
# 120                  313865                  255435  ...
# 121                     809                    1974  ...
# 122                      81                      17  ...
# 123                     176                     146  ...
# 124                      77                      89  ...
#
#      Population - Age 18+  Population - Age 65+  Population - Female  \
# 120               2146679                342174              1388469
# 121                 13688                  2605                 7894
# 122                  1481                     4                  744
# 123                  1171                   198                  560
# 124                   724                    65                  441
#
#      Population - Male  Population - Latinx  Population - Asian Non-Latinx  \
# 120            1310878               772791                       182251.0
# 121               6619                 1242                         3528.0
# 122                852                  120                          435.0
# 123                626                   62                          397.0
# 124                288                   23                          127.0
#
#      Population - Black Non-Latinx  Population - White Non-Latinx  \
# 120                       776470.0                         900055
# 121                          679.0                           8614
# 122                           37.0                            794
# 123                           29.0                            692
# 124                           72.0                            507
#
#      Population - Other Race Non-Latinx              Record ID
# 120                             67780.0  Citywide-Chicago-2020
# 121                               450.0    ZIP_CODE-60601-2020
# 122                               210.0    ZIP_CODE-60602-2020
# 123                                 6.0    ZIP_CODE-60603-2020
# 124                                 0.0    ZIP_CODE-60604-2020
#
# [5 rows x 26 columns]

# %%
# list all columns in the dataframe
chicago_pop_counts_2020_df.columns
# Out:
# Index(['Geography Type', 'Year', 'Geography', 'Population - Total',
#        'Population - Age 0-17', 'Population - Age 18-29',
#        'Population - Age 30-39', 'Population - Age 40-49',
#        'Population - Age 50-59', 'Population - Age 60-69',
#        'Population - Age 70-79', 'Population - Age 80+',
#        'Population - Age 0-4', 'Population - Age 5-11',
#        'Population - Age 12-17', 'Population - Age 5+', 'Population - Age 18+',
#        'Population - Age 65+', 'Population - Female', 'Population - Male',
#        'Population - Latinx', 'Population - Asian Non-Latinx',
#        'Population - Black Non-Latinx', 'Population - White Non-Latinx',
#        'Population - Other Race Non-Latinx', 'Record ID'],
#       dtype='object')

# %%
# Rename columns to get rid of population in the title. 
chicago_pop_counts_2020_df = chicago_pop_counts_2020_df.rename(columns={'Population - Total': 'Total', 
                                                                        'Population - Age 0-17': 'Age 0-17', 
                                                                        'Population - Age 18-29': 'Age 18-29',
                                                                        'Population - Age 30-39': 'Age 30-39',
                                                                        'Population - Age 40-49': 'Age 40-49',
                                                                        'Population - Age 50-59': 'Age 50-59',
                                                                        'Population - Age 60-69': 'Age 60-69',
                                                                        'Population - Age 70-79': 'Age 70-79',
                                                                        'Population - Age 80+': 'Age 80+',
                                                                        'Population - Female': 'Female',
                                                                        'Population - Male': 'Male',
                                                                        'Population - Latinx': 'Latinx',
                                                                        'Population - Asian Non-Latinx': 'Asian Non-Latinx',
                                                                        'Population - Black Non-Latinx': 'Black Non-Latinx',
                                                                        'Population - White Non-Latinx': 'White Non-Latinx',
                                                                        'Population - Other Non-Latinx': 'Other Non-Latinx',
                                                                })
chicago_pop_counts_2020_df.head()
# Out:
#     Geography Type  Year Geography    Total  Age 0-17  Age 18-29  Age 30-39  \
# 120       Citywide  2020   Chicago  2699347    552668     548747     463143
# 121       ZIP Code  2020     60601    14513       825       4696       3048
# 122       ZIP Code  2020     60602     1596       115        332        860
# 123       ZIP Code  2020     60603     1186        15        423        248
# 124       ZIP Code  2020     60604      729         5        313        171
#
#      Age 40-49  Age 50-59  Age 60-69  ...  Population - Age 18+  \
# 120     336591     313865     255435  ...               2146679
# 121       1815        809       1974  ...                 13688
# 122        191         81         17  ...                  1481
# 123         68        176        146  ...                  1171
# 124         30         77         89  ...                   724
#
#      Population - Age 65+   Female     Male  Latinx  Asian Non-Latinx  \
# 120                342174  1388469  1310878  772791          182251.0
# 121                  2605     7894     6619    1242            3528.0
# 122                     4      744      852     120             435.0
# 123                   198      560      626      62             397.0
# 124                    65      441      288      23             127.0
#
#      Black Non-Latinx  White Non-Latinx  Population - Other Race Non-Latinx  \
# 120          776470.0            900055                             67780.0
# 121             679.0              8614                               450.0
# 122              37.0               794                               210.0
# 123              29.0               692                                 6.0
# 124              72.0               507                                 0.0
#
#                  Record ID
# 120  Citywide-Chicago-2020
# 121    ZIP_CODE-60601-2020
# 122    ZIP_CODE-60602-2020
# 123    ZIP_CODE-60603-2020
# 124    ZIP_CODE-60604-2020
#
# [5 rows x 26 columns]

# %%
# Drop columns that are not needed ('Population - Age 0-4', 'Population - Age 5-11', 'Population - Age 12-17', 'Population - Age 5+', 'Population - Age 18+', 'Population - Age 65+', "Record ID")

chicago_pop_counts_2020_df = chicago_pop_counts_2020_df.drop(columns=['Population - Age 0-4', 
                                                                      'Population - Age 5-11', 
                                                                      'Population - Age 12-17', 
                                                                      'Population - Age 5+', 
                                                                      'Population - Age 18+', 
                                                                      'Population - Age 65+', 
                                                                      'Record ID'])
chicago_pop_counts_2020_df.head()
# Out:
#     Geography Type  Year Geography    Total  Age 0-17  Age 18-29  Age 30-39  \
# 120       Citywide  2020   Chicago  2699347    552668     548747     463143
# 121       ZIP Code  2020     60601    14513       825       4696       3048
# 122       ZIP Code  2020     60602     1596       115        332        860
# 123       ZIP Code  2020     60603     1186        15        423        248
# 124       ZIP Code  2020     60604      729         5        313        171
#
#      Age 40-49  Age 50-59  Age 60-69  Age 70-79  Age 80+   Female     Male  \
# 120     336591     313865     255435     145426    83472  1388469  1310878
# 121       1815        809       1974       1070      276     7894     6619
# 122        191         81         17          0        0      744      852
# 123         68        176        146         91       19      560      626
# 124         30         77         89         36        8      441      288
#
#      Latinx  Asian Non-Latinx  Black Non-Latinx  White Non-Latinx  \
# 120  772791          182251.0          776470.0            900055
# 121    1242            3528.0             679.0              8614
# 122     120             435.0              37.0               794
# 123      62             397.0              29.0               692
# 124      23             127.0              72.0               507
#
#      Population - Other Race Non-Latinx
# 120                             67780.0
# 121                               450.0
# 122                               210.0
# 123                                 6.0
# 124                                 0.0

# %%
# Save new cleaned data to a new csv file
chicago_pop_counts_2020_df.to_csv('cleaned_data/chicago_pop_counts_2020.csv', index=False)

# %% [markdown]
# ## Economic Metric
#
# **Measuring**: Median Household Income, Unemployment Rate, Poverty Rate.
#
# Data for this section was pulled from the Chicago 2020 Census Database using various coded tables:
# * Median Household Income: Table S1901
# * Unemployment Rate: Table S2301
# * Poverty Rate: S1501

# %% [markdown]
# ##### Median Household Income (Table S1901)

# %%
# Import new csv file for Median Household Income
chicago_income_data = '../chicago_data/chi_median_income.csv'

# Read the csv file
chicago_income_df = pd.read_csv(chicago_income_data)
chicago_income_df.head()
# Out:
#          Label (Grouping) Illinois!!Households!!Estimate  \
# 0                   Total                      4,884,061
# 1       Less than $10,000                           6.1%
# 2      $10,000 to $14,999                           3.7%
# 3      $15,000 to $24,999                           8.1%
# 4      $25,000 to $34,999                           8.1%
#
#   Illinois!!Households!!Margin of Error Illinois!!Families!!Estimate  \
# 0                                ±8,585                    3,116,415
# 1                                  ±0.1                         3.3%
# 2                                  ±0.1                         2.0%
# 3                                  ±0.1                         5.3%
# 4                                  ±0.1                         6.3%
#
#   Illinois!!Families!!Margin of Error  \
# 0                             ±10,228
# 1                                ±0.1
# 2                                ±0.1
# 3                                ±0.1
# 4                                ±0.1
#
#   Illinois!!Married-couple families!!Estimate  \
# 0                                   2,301,114
# 1                                        1.2%
# 2                                        0.9%
# 3                                        2.8%
# 4                                        4.3%
#
#   Illinois!!Married-couple families!!Margin of Error  \
# 0                                            ±11,693
# 1                                               ±0.1
# 2                                               ±0.1
# 3                                               ±0.1
# 4                                               ±0.1
#
#   Illinois!!Nonfamily households!!Estimate  \
# 0                                1,767,646
# 1                                    11.9%
# 2                                     7.0%
# 3                                    13.8%
# 4                                    11.7%
#
#   Illinois!!Nonfamily households!!Margin of Error  \
# 0                                          ±7,877
# 1                                            ±0.2
# 2                                            ±0.1
# 3                                            ±0.2
# 4                                            ±0.2
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Households!!Estimate  \
# 0                                          3,548,735
# 1                                               5.8%
# 2                                               3.3%
# 3                                               7.3%
# 4                                               7.4%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Households!!Margin of Error  \
# 0                                             ±5,885
# 1                                               ±0.1
# 2                                               ±0.1
# 3                                               ±0.1
# 4                                               ±0.1
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Families!!Estimate  \
# 0                                          2,288,602
# 1                                               3.3%
# 2                                               1.8%
# 3                                               4.9%
# 4                                               6.0%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Families!!Margin of Error  \
# 0                                             ±9,235
# 1                                               ±0.1
# 2                                               ±0.1
# 3                                               ±0.1
# 4                                               ±0.1
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Married-couple families!!Estimate  \
# 0                                          1,671,999
# 1                                               1.1%
# 2                                               0.8%
# 3                                               2.7%
# 4                                               4.0%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Married-couple families!!Margin of Error  \
# 0                                            ±10,169
# 1                                               ±0.1
# 2                                               ±0.1
# 3                                               ±0.1
# 4                                               ±0.1
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Nonfamily households!!Estimate  \
# 0                                          1,260,133
# 1                                              11.2%
# 2                                               6.2%
# 3                                              12.3%
# 4                                              10.6%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Nonfamily households!!Margin of Error
# 0                                             ±7,479
# 1                                               ±0.2
# 2                                               ±0.2
# 3                                               ±0.2
# 4                                               ±0.2

# %%
# Display columns and data types
chicago_income_df.dtypes
# Out:
# Label (Grouping)                                                                           object
# Illinois!!Households!!Estimate                                                             object
# Illinois!!Households!!Margin of Error                                                      object
# Illinois!!Families!!Estimate                                                               object
# Illinois!!Families!!Margin of Error                                                        object
# Illinois!!Married-couple families!!Estimate                                                object
# Illinois!!Married-couple families!!Margin of Error                                         object
# Illinois!!Nonfamily households!!Estimate                                                   object
# Illinois!!Nonfamily households!!Margin of Error                                            object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Households!!Estimate                        object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Households!!Margin of Error                 object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Families!!Estimate                          object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Families!!Margin of Error                   object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Married-couple families!!Estimate           object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Married-couple families!!Margin of Error    object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Nonfamily households!!Estimate              object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Nonfamily households!!Margin of Error       object
# dtype: object

# %%
# Drop unnecessary columns (i.e anything with "Margin of Error")
chicago_income_df = chicago_income_df.drop(columns=['Illinois!!Households!!Margin of Error', 
                                                    'Illinois!!Families!!Margin of Error', 
                                                    'Illinois!!Married-couple families!!Margin of Error',
                                                    'Illinois!!Nonfamily households!!Margin of Error',
                                                    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Households!!Margin of Error',
                                                    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Families!!Margin of Error',
                                                    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Married-couple families!!Margin of Error',
                                                    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Nonfamily households!!Margin of Error'
                                                    ])

# %%
# Rename columns for clarity
chicago_income_df = chicago_income_df.rename(columns={
    'Label (Grouping)': 'Income Grouping',
    'Illinois!!Households!!Estimate': 'Illinois Households',
    'Illinois!!Families!!Estimate': 'Illinois Families',
    'Illinois!!Married-couple families!!Estimate': 'Illinois Married-couple Households',
    'Illinois!!Nonfamily households!!Estimate': 'Illinois Nonfamily Households',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Households!!Estimate': 'Chicago Metro Households',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Families!!Estimate': 'Chicago Metro Families',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Married-couple families!!Estimate': 'Chicago Metro Married-couple Households',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Nonfamily households!!Estimate': 'Chicago Metro Nonfamily Households'
})

# Display the cleaned DataFrame
chicago_income_df.head()
# Out:
#           Income Grouping Illinois Households Illinois Families  \
# 0                   Total           4,884,061         3,116,415
# 1       Less than $10,000                6.1%              3.3%
# 2      $10,000 to $14,999                3.7%              2.0%
# 3      $15,000 to $24,999                8.1%              5.3%
# 4      $25,000 to $34,999                8.1%              6.3%
#
#   Illinois Married-couple Households Illinois Nonfamily Households  \
# 0                          2,301,114                     1,767,646
# 1                               1.2%                         11.9%
# 2                               0.9%                          7.0%
# 3                               2.8%                         13.8%
# 4                               4.3%                         11.7%
#
#   Chicago Metro Households Chicago Metro Families  \
# 0                3,548,735              2,288,602
# 1                     5.8%                   3.3%
# 2                     3.3%                   1.8%
# 3                     7.3%                   4.9%
# 4                     7.4%                   6.0%
#
#   Chicago Metro Married-couple Households Chicago Metro Nonfamily Households
# 0                               1,671,999                          1,260,133
# 1                                    1.1%                              11.2%
# 2                                    0.8%                               6.2%
# 3                                    2.7%                              12.3%
# 4                                    4.0%                              10.6%

# %%
# Save the cleaned DataFrame to a new CSV file

# %% [markdown]
# ##### Unemployment Rate (Table S2301)

# %%
# Import new csv file for Unemployment Rate
chicago_employment_data = '../chicago_data/chi_employment_status.csv'

# Read the csv file
chicago_employment_df = pd.read_csv(chicago_employment_data)
chicago_employment_df.head()
# Out:
#                Label (Grouping) Illinois!!Total!!Estimate  \
# 0  Population 16 years and over                10,193,604
# 1                           AGE                       NaN
# 2                16 to 19 years                   662,629
# 3                20 to 24 years                   844,275
# 4                25 to 29 years                   896,223
#
#   Illinois!!Total!!Margin of Error  \
# 0                           ±2,843
# 1                              NaN
# 2                           ±2,868
# 3                           ±1,252
# 4                             ±929
#
#   Illinois!!Labor Force Participation Rate!!Estimate  \
# 0                                              65.2%
# 1                                                NaN
# 2                                              40.1%
# 3                                              75.6%
# 4                                              85.1%
#
#   Illinois!!Labor Force Participation Rate!!Margin of Error  \
# 0                                               ±0.1
# 1                                                NaN
# 2                                               ±0.4
# 3                                               ±0.4
# 4                                               ±0.3
#
#   Illinois!!Employment/Population Ratio!!Estimate  \
# 0                                           61.2%
# 1                                             NaN
# 2                                           32.4%
# 3                                           66.8%
# 4                                           79.1%
#
#   Illinois!!Employment/Population Ratio!!Margin of Error  \
# 0                                               ±0.1
# 1                                                NaN
# 2                                               ±0.4
# 3                                               ±0.4
# 4                                               ±0.4
#
#   Illinois!!Unemployment rate!!Estimate  \
# 0                                  6.0%
# 1                                   NaN
# 2                                 18.1%
# 3                                 11.0%
# 4                                  6.7%
#
#   Illinois!!Unemployment rate!!Margin of Error  \
# 0                                         ±0.1
# 1                                          NaN
# 2                                         ±0.6
# 3                                         ±0.3
# 4                                         ±0.3
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate  \
# 0                                          7,572,022
# 1                                                NaN
# 2                                            491,955
# 3                                            617,600
# 4                                            691,955
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error  \
# 0                                             ±2,220
# 1                                                NaN
# 2                                             ±2,371
# 3                                               ±624
# 4                                               ±452
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Labor Force Participation Rate!!Estimate  \
# 0                                              66.9%
# 1                                                NaN
# 2                                              38.2%
# 3                                              76.5%
# 4                                              85.8%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Labor Force Participation Rate!!Margin of Error  \
# 0                                               ±0.1
# 1                                                NaN
# 2                                               ±0.5
# 3                                               ±0.4
# 4                                               ±0.3
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Employment/Population Ratio!!Estimate  \
# 0                                              62.6%
# 1                                                NaN
# 2                                              30.5%
# 3                                              66.7%
# 4                                              79.6%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Employment/Population Ratio!!Margin of Error  \
# 0                                               ±0.1
# 1                                                NaN
# 2                                               ±0.5
# 3                                               ±0.5
# 4                                               ±0.4
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Unemployment rate!!Estimate  \
# 0                                               6.2%
# 1                                                NaN
# 2                                              19.0%
# 3                                              12.0%
# 4                                               6.8%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Unemployment rate!!Margin of Error
# 0                                               ±0.1
# 1                                                NaN
# 2                                               ±0.7
# 3                                               ±0.4
# 4                                               ±0.3

# %%
# Display columns and data types
chicago_employment_df.dtypes
# Out:
# Label (Grouping)                                                                                  object
# Illinois!!Total!!Estimate                                                                         object
# Illinois!!Total!!Margin of Error                                                                  object
# Illinois!!Labor Force Participation Rate!!Estimate                                                object
# Illinois!!Labor Force Participation Rate!!Margin of Error                                         object
# Illinois!!Employment/Population Ratio!!Estimate                                                   object
# Illinois!!Employment/Population Ratio!!Margin of Error                                            object
# Illinois!!Unemployment rate!!Estimate                                                             object
# Illinois!!Unemployment rate!!Margin of Error                                                      object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate                                    object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error                             object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Labor Force Participation Rate!!Estimate           object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Labor Force Participation Rate!!Margin of Error    object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Employment/Population Ratio!!Estimate              object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Employment/Population Ratio!!Margin of Error       object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Unemployment rate!!Estimate                        object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Unemployment rate!!Margin of Error                 object
# dtype: object

# %%
# Drop unnecessary columns (i.e anything with "Margin of Error")
chicago_employment_df = chicago_employment_df.drop(columns=['Illinois!!Total!!Margin of Error', 
                                                            'Illinois!!Labor Force Participation Rate!!Margin of Error', 
                                                            'Illinois!!Employment/Population Ratio!!Margin of Error',
                                                            'Illinois!!Unemployment rate!!Margin of Error',
                                                            'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error',
                                                            'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Labor Force Participation Rate!!Margin of Error',
                                                            'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Employment/Population Ratio!!Margin of Error',
                                                            'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Unemployment rate!!Margin of Error'
                                                            ])

# %%
# Drop Nan Values
chicago_employment_df = chicago_employment_df.dropna()

# %%
# Rename columns for clarity
chicago_employment_df = chicago_employment_df.rename(columns={
    'Label (Grouping)': 'Age',
    'Illinois!!Total!!Estimate': 'Illinois Total',
    'Illinois!!Labor Force Participation Rate!!Estimate': 'Illinois Labor Force Participation Rate',
    'Illinois!!Employment/Population Ratio!!Estimate': 'Illinois Employment/Population Ratio',
    'Illinois!!Unemployment rate!!Estimate': 'Illinois Unemployment Rate',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate': 'Chicago Metro Total Population',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Labor Force Participation Rate!!Estimate': 'Chicago Metro Labor Force Participation Rate',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Employment/Population Ratio!!Estimate': 'Chicago Metro Employment/Population Ratio',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Unemployment rate!!Estimate': 'Chicago Metro Unemployment Rate'
})

# Display the cleaned DataFrame
chicago_employment_df.head()
# Out:
#                             Age Illinois Total  \
# 0  Population 16 years and over     10,193,604
# 2                16 to 19 years        662,629
# 3                20 to 24 years        844,275
# 4                25 to 29 years        896,223
# 5                30 to 34 years        867,606
#
#   Illinois Labor Force Participation Rate  \
# 0                                   65.2%
# 2                                   40.1%
# 3                                   75.6%
# 4                                   85.1%
# 5                                   85.6%
#
#   Illinois Employment/Population Ratio Illinois Unemployment Rate  \
# 0                                61.2%                       6.0%
# 2                                32.4%                      18.1%
# 3                                66.8%                      11.0%
# 4                                79.1%                       6.7%
# 5                                80.9%                       5.2%
#
#   Chicago Metro Total Population Chicago Metro Labor Force Participation Rate  \
# 0                      7,572,022                                        66.9%
# 2                        491,955                                        38.2%
# 3                        617,600                                        76.5%
# 4                        691,955                                        85.8%
# 5                        673,000                                        86.2%
#
#   Chicago Metro Employment/Population Ratio Chicago Metro Unemployment Rate
# 0                                     62.6%                            6.2%
# 2                                     30.5%                           19.0%
# 3                                     66.7%                           12.0%
# 4                                     79.6%                            6.8%
# 5                                     81.4%                            5.2%

# %%
# Save the cleaned DataFrame to a new CSV file

# %% [markdown]
# #### Poverty Rate (S1501)

# %%
# Import new csv file for Poverty Rate
chicago_poverty_data = '../chicago_data/chi_poverty_status.csv'

# Read the csv file
chicago_poverty_df = pd.read_csv(chicago_poverty_data)
chicago_poverty_df.head()
# Out:
#                                    Label (Grouping) Illinois!!Total!!Estimate  \
# 0  Population for whom poverty status is determined                12,418,504
# 1                                               AGE                       NaN
# 2                                    Under 18 years                 2,813,715
# 3                                     Under 5 years                   742,571
# 4                                     5 to 17 years                 2,071,144
#
#   Illinois!!Total!!Margin of Error Illinois!!Below poverty level!!Estimate  \
# 0                           ±2,377                               1,488,670
# 1                              NaN                                     NaN
# 2                           ±2,419                                 454,654
# 3                           ±1,463                                 130,683
# 4                           ±1,695                                 323,971
#
#   Illinois!!Below poverty level!!Margin of Error  \
# 0                                        ±18,242
# 1                                            NaN
# 2                                         ±9,623
# 3                                         ±3,603
# 4                                         ±7,648
#
#   Illinois!!Percent below poverty level!!Estimate  \
# 0                                           12.0%
# 1                                             NaN
# 2                                           16.2%
# 3                                           17.6%
# 4                                           15.6%
#
#   Illinois!!Percent below poverty level!!Margin of Error  \
# 0                                               ±0.1
# 1                                                NaN
# 2                                               ±0.3
# 3                                               ±0.5
# 4                                               ±0.4
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate  \
# 0                                          9,319,224
# 1                                                NaN
# 2                                          2,133,785
# 3                                            559,864
# 4                                          1,573,921
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error  \
# 0                                             ±3,122
# 1                                                NaN
# 2                                             ±1,927
# 3                                             ±1,254
# 4                                             ±1,315
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Below poverty level!!Estimate  \
# 0                                          1,052,416
# 1                                                NaN
# 2                                            331,541
# 3                                             90,114
# 4                                            241,427
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Below poverty level!!Margin of Error  \
# 0                                            ±15,120
# 1                                                NaN
# 2                                             ±8,005
# 3                                             ±2,880
# 4                                             ±6,823
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent below poverty level!!Estimate  \
# 0                                              11.3%
# 1                                                NaN
# 2                                              15.5%
# 3                                              16.1%
# 4                                              15.3%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent below poverty level!!Margin of Error
# 0                                               ±0.2
# 1                                                NaN
# 2                                               ±0.4
# 3                                               ±0.5
# 4                                               ±0.4

# %%
# Display columns and data types
chicago_poverty_df.dtypes
# Out:
# Label (Grouping)                                                                               object
# Illinois!!Total!!Estimate                                                                      object
# Illinois!!Total!!Margin of Error                                                               object
# Illinois!!Below poverty level!!Estimate                                                        object
# Illinois!!Below poverty level!!Margin of Error                                                 object
# Illinois!!Percent below poverty level!!Estimate                                                object
# Illinois!!Percent below poverty level!!Margin of Error                                         object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate                                 object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error                          object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Below poverty level!!Estimate                   object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Below poverty level!!Margin of Error            object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent below poverty level!!Estimate           object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent below poverty level!!Margin of Error    object
# dtype: object

# %%
# Drop unnecessary columns (i.e anything with "Margin of Error")
chicago_poverty_df = chicago_poverty_df.drop(columns=['Illinois!!Total!!Margin of Error', 
                                                       'Illinois!!Below poverty level!!Margin of Error', 
                                                       'Illinois!!Percent below poverty level!!Margin of Error',
                                                       'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error',
                                                       'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Below poverty level!!Margin of Error',
                                                       'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent below poverty level!!Margin of Error'
                                                       ])

# %%
# Delete NaN values
chicago_poverty_df = chicago_poverty_df.dropna()

# %%
# Rename columns
chicago_poverty_df = chicago_poverty_df.rename(columns={
    'Label (Grouping)': 'Age',
    'Illinois!!Total!!Estimate': 'Illinois Total Population',
    'Illinois!!Below poverty level!!Estimate': 'Illinois Below Poverty Level',
    'Illinois!!Percent below poverty level!!Estimate': 'Illinois % Below Poverty Level',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate': 'Chicago Metro Total Population',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Below poverty level!!Estimate': 'Chicago Metro Below Poverty Level',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent below poverty level!!Estimate': 'Chicago Metro % Below Poverty Level'
})

# Display the cleaned DataFrame
chicago_poverty_df.head()
# Out:
#                                                  Age  \
# 0   Population for whom poverty status is determined
# 2                                     Under 18 years
# 3                                      Under 5 years
# 4                                      5 to 17 years
# 5              Related children of householder un...
#
#   Illinois Total Population Illinois Below Poverty Level  \
# 0                12,418,504                    1,488,670
# 2                 2,813,715                      454,654
# 3                   742,571                      130,683
# 4                 2,071,144                      323,971
# 5                 2,802,857                      444,689
#
#   Illinois % Below Poverty Level Chicago Metro Total Population  \
# 0                          12.0%                      9,319,224
# 2                          16.2%                      2,133,785
# 3                          17.6%                        559,864
# 4                          15.6%                      1,573,921
# 5                          15.9%                      2,126,805
#
#   Chicago Metro Below Poverty Level Chicago Metro % Below Poverty Level
# 0                         1,052,416                               11.3%
# 2                           331,541                               15.5%
# 3                            90,114                               16.1%
# 4                           241,427                               15.3%
# 5                           325,159                               15.3%

# %%
# Save the cleaned DataFrame to a new CSV file

# %% [markdown]
# ## Housing  Metric
#
# **Measuring**: Median Home Price, Median Rent, Homeownership Rate
#
# Data for this section was pulled from the Chicago 2020 Census Database using the same table code from the American Community Survey by the U.S. Census Bureau (ACS).
# * Median Home Price: Table DP04
# * Median Rent: Table DP04
# * Homeownership Rate: Table DP04

# %%
# Import new csv file for Housing Metric
chicago_housing_data = '../chicago_data/chi_housing.csv'

# Read the csv file
chicago_housing_df = pd.read_csv(chicago_housing_data)
chicago_housing_df.head()
# Out:
#                  Label (Grouping) Illinois!!Estimate  \
# 0               HOUSING OCCUPANCY                NaN
# 1             Total housing units          5,373,385
# 2          Occupied housing units          4,884,061
# 3            Vacant housing units            489,324
# 4          Homeowner vacancy rate                1.6
#
#   Illinois!!Margin of Error Illinois!!Percent  \
# 0                       NaN               NaN
# 1                      ±564         5,373,385
# 2                    ±8,585             90.9%
# 3                    ±8,662              9.1%
# 4                      ±0.1               (X)
#
#   Illinois!!Percent Margin of Error  \
# 0                               NaN
# 1                               (X)
# 2                              ±0.2
# 3                              ±0.2
# 4                               (X)
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Estimate  \
# 0                                                NaN
# 1                                          3,856,019
# 2                                          3,548,735
# 3                                            307,284
# 4                                                1.5
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Margin of Error  \
# 0                                                NaN
# 1                                               ±936
# 2                                             ±5,885
# 3                                             ±5,724
# 4                                               ±0.1
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent  \
# 0                                                NaN
# 1                                          3,856,019
# 2                                              92.0%
# 3                                               8.0%
# 4                                                (X)
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Margin of Error
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.1
# 3                                               ±0.1
# 4                                                (X)

# %%
# Display columns and data types
chicago_housing_df.dtypes
# Out:
# Label (Grouping)                                                          object
# Illinois!!Estimate                                                        object
# Illinois!!Margin of Error                                                 object
# Illinois!!Percent                                                         object
# Illinois!!Percent Margin of Error                                         object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Estimate                   object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Margin of Error            object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent                    object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Margin of Error    object
# dtype: object

# %%
# Drop unnecessary columns (i.e anything with "Margin of Error")
chicago_housing_df = chicago_housing_df.drop(columns=['Illinois!!Margin of Error',
                                                            'Illinois!!Percent Margin of Error',
                                                            'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Margin of Error',
                                                            'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent Margin of Error'])

# %%
# Delete NaN values from the DataFrame
chicago_housing_df = chicago_housing_df.dropna()

# %%
# Rename columns 
chicago_housing_df = chicago_housing_df.rename(columns={
    'Label (Grouping)': 'Housing Occupancy Status',
    'Illinois!!Estimate': 'Illinois Total Housing Units',
    'Illinois!!Percent': 'Illinois % Housing Units',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Estimate': 'Chicago Metro Total Housing Units',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Percent': 'Chicago Metro % Housing Units'
})

# Display the cleaned DataFrame
chicago_housing_df.head()
# Out:
#          Housing Occupancy Status Illinois Total Housing Units  \
# 1             Total housing units                    5,373,385
# 2          Occupied housing units                    4,884,061
# 3            Vacant housing units                      489,324
# 4          Homeowner vacancy rate                          1.6
# 5             Rental vacancy rate                          5.9
#
#   Illinois % Housing Units Chicago Metro Total Housing Units  \
# 1                5,373,385                         3,856,019
# 2                    90.9%                         3,548,735
# 3                     9.1%                           307,284
# 4                      (X)                               1.5
# 5                      (X)                               5.3
#
#   Chicago Metro % Housing Units
# 1                     3,856,019
# 2                         92.0%
# 3                          8.0%
# 4                           (X)
# 5                           (X)

# %%
# Save the cleaned DataFrame to a new CSV file

# %% [markdown]
# ## Quality of Life Metric
#
# **Measuring**: Commute Time
#
# Data was pulled from the Census Database using the following survey by ASC in 2020.
# * Commute Time: Table S0801

# %%
# Import new csv file for Commute Time
chicago_commute_data = '../chicago_data/chi_commute.csv'

# Read the csv file
chicago_commute_df = pd.read_csv(chicago_commute_data)
chicago_commute_df.head()
# Out:
#                       Label (Grouping) Illinois!!Total!!Estimate  \
# 0            Workers 16 years and over                 6,129,176
# 1      MEANS OF TRANSPORTATION TO WORK                       NaN
# 2                   Car, truck, or van                     79.3%
# 3                          Drove alone                     71.5%
# 4                            Carpooled                      7.8%
#
#   Illinois!!Total!!Margin of Error Illinois!!Male!!Estimate  \
# 0                          ±12,308                3,211,679
# 1                              NaN                      NaN
# 2                             ±0.2                    79.7%
# 3                             ±0.2                    71.9%
# 4                             ±0.1                     7.8%
#
#   Illinois!!Male!!Margin of Error Illinois!!Female!!Estimate  \
# 0                          ±7,869                  2,917,497
# 1                             NaN                        NaN
# 2                            ±0.2                      78.9%
# 3                            ±0.2                      71.1%
# 4                            ±0.1                       7.8%
#
#   Illinois!!Female!!Margin of Error  \
# 0                            ±8,018
# 1                               NaN
# 2                              ±0.2
# 3                              ±0.2
# 4                              ±0.1
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate  \
# 0                                          4,654,790
# 1                                                NaN
# 2                                              76.1%
# 3                                              68.3%
# 4                                               7.7%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error  \
# 0                                            ±10,685
# 1                                                NaN
# 2                                               ±0.2
# 3                                               ±0.2
# 4                                               ±0.1
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Estimate  \
# 0                                          2,453,220
# 1                                                NaN
# 2                                              76.7%
# 3                                              69.1%
# 4                                               7.5%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Margin of Error  \
# 0                                             ±7,291
# 1                                                NaN
# 2                                               ±0.2
# 3                                               ±0.3
# 4                                               ±0.2
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Estimate  \
# 0                                          2,201,570
# 1                                                NaN
# 2                                              75.4%
# 3                                              67.5%
# 4                                               7.9%
#
#   Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Margin of Error
# 0                                             ±7,397
# 1                                                NaN
# 2                                               ±0.3
# 3                                               ±0.3
# 4                                               ±0.2

# %%
# Display columns and data types
chicago_commute_df.dtypes
# Out:
# Label (Grouping)                                                          object
# Illinois!!Total!!Estimate                                                 object
# Illinois!!Total!!Margin of Error                                          object
# Illinois!!Male!!Estimate                                                  object
# Illinois!!Male!!Margin of Error                                           object
# Illinois!!Female!!Estimate                                                object
# Illinois!!Female!!Margin of Error                                         object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate            object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error     object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Estimate             object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Margin of Error      object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Estimate           object
# Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Margin of Error    object
# dtype: object

# %%
# Delete unnecessary columns (i.e anything with "Margin of Error")
chicago_commute_df = chicago_commute_df.drop(columns=['Illinois!!Total!!Margin of Error',
                                                        'Illinois!!Male!!Margin of Error',
                                                        'Illinois!!Female!!Margin of Error',
                                                        'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Margin of Error',
                                                        'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Margin of Error',
                                                        'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Margin of Error'
                                                        ])

# %%
# Delete NaN values
chicago_commute_df = chicago_commute_df.dropna()

# %%
# Rename columns for clarity
chicago_commute_df = chicago_commute_df.rename(columns={
    'Label (Grouping)': 'Means of Transportation',
    'Illinois!!Total!!Estimate': 'Illinois Total Commute Time',
    'Illinois!!Male!!Estimate': 'Male Total',
    'Illinois!!Female!!Estimate': 'Female Total',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Total!!Estimate': 'Chicago Metro Total',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Male!!Estimate': 'Chicago Male Total',
    'Chicago-Naperville-Elgin, IL-IN-WI Metro Area!!Female!!Estimate': 'Chicago Female Total'
})

# Display the cleaned DataFrame
chicago_commute_df.head()
# Out:
#                Means of Transportation Illinois Total Commute Time  \
# 0            Workers 16 years and over                   6,129,176
# 2                   Car, truck, or van                       79.3%
# 3                          Drove alone                       71.5%
# 4                            Carpooled                        7.8%
# 5                  In 2-person carpool                        5.9%
#
#   Illinois Male Total Illinois Female Total Chicago Metro Total  \
# 0           3,211,679             2,917,497           4,654,790
# 2               79.7%                 78.9%               76.1%
# 3               71.9%                 71.1%               68.3%
# 4                7.8%                  7.8%                7.7%
# 5                5.9%                  5.9%                5.8%
#
#   Chicago Male Total Chicago Female Total
# 0          2,453,220            2,201,570
# 2              76.7%                75.4%
# 3              69.1%                67.5%
# 4               7.5%                 7.9%
# 5               5.7%                 6.0%

# %% [markdown]
# ## THIS IS A DATASET COMPARING CHICAGO FROM 2020 TO 2024. MIGHT WANT TO KEEP.

# %%
## THIS IS A DATASET COMPARING CHICAGO FROM 2020 TO 2024. MIGHT WANT TO KEEP.
# Import csv file for chicago_data
chicago_data = 'data_files/chicago_data/chicago_demographics.csv'

# Read the csv file for chicago_data
chicago_data_df = pd.read_csv(chicago_data)
chicago_data_df.head()
# Out:
#                                                 Fact Fact Note  \
# 0        Population estimates, July 1, 2024, (V2024)       NaN
# 1        Population estimates, July 1, 2023, (V2023)       NaN
# 2  Population estimates base, April 1, 2020, (V2024)       NaN
# 3  Population estimates base, April 1, 2020, (V2023)       NaN
# 4  Population, percent change - April 1, 2020 (es...       NaN
#
#   Chicago city, Illinois  Value Note for Chicago city, Illinois
# 0                    NaN                                    NaN
# 1              2,664,452                                    NaN
# 2                    NaN                                    NaN
# 3              2,746,352                                    NaN
# 4                    NaN                                    NaN

# %%
# Filter the dataframe to only include rows with '2020' in the 'Fact' column
chicago_data_2020_df = chicago_data_df[chicago_data_df['Fact'].str.contains('2020')]
chicago_data_2020_df
# Out:
#                                                  Fact Fact Note  \
# 2   Population estimates base, April 1, 2020, (V2024)       NaN
# 3   Population estimates base, April 1, 2020, (V2023)       NaN
# 4   Population, percent change - April 1, 2020 (es...       NaN
# 5   Population, percent change - April 1, 2020 (es...       NaN
# 6                   Population, Census, April 1, 2020       NaN
# 62                   Population per square mile, 2020       NaN
# 64                    Land area in square miles, 2020       NaN
#
#    Chicago city, Illinois  Value Note for Chicago city, Illinois
# 2                     NaN                                    NaN
# 3               2,746,352                                    NaN
# 4                     NaN                                    NaN
# 5                   -3.0%                                    NaN
# 6               2,746,388                                    NaN
# 62               12,059.8                                    NaN
# 64                 227.73                                    NaN

# %%
# Clean the data by dropping the columns that are not needed (want to drop "Fact Note", "Value Note for Chicago City, Illinois") 
chicago_data_2020_df = chicago_data_2020_df.drop(columns=['Fact Note', 'Value Note for Chicago city, Illinois'])
chicago_data_2020_df.head()
# Out:
#                                                 Fact Chicago city, Illinois
# 2  Population estimates base, April 1, 2020, (V2024)                    NaN
# 3  Population estimates base, April 1, 2020, (V2023)              2,746,352
# 4  Population, percent change - April 1, 2020 (es...                    NaN
# 5  Population, percent change - April 1, 2020 (es...                  -3.0%
# 6                  Population, Census, April 1, 2020              2,746,388

# %%
# Drop the rows with NaN values
chicago_data_2020_df = chicago_data_2020_df.dropna()

# %%
chicago_data_2020_df.head()
# Out:
#                                                  Fact Chicago city, Illinois
# 3   Population estimates base, April 1, 2020, (V2023)              2,746,352
# 5   Population, percent change - April 1, 2020 (es...                  -3.0%
# 6                   Population, Census, April 1, 2020              2,746,388
# 62                   Population per square mile, 2020               12,059.8
# 64                    Land area in square miles, 2020                 227.73

# %%
# save the cleaned data to a new csv file
chicago_data_2020_df.to_csv('cleaned_data/chicago_data_2020.csv', index=False)
